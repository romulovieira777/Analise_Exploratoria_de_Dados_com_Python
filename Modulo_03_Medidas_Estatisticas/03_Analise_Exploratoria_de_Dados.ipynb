# %% [markdown]
# ## Análise Exploratoria de Dados

# %% [markdown]
# # Ferramentas e Bibliotecas

# %% [markdown]
# *   [Google Colab](https://colab.google/): Serviço de nuvem gratuito hospedado pelo Google para incentivar a pesquisa de Aprendizado de Máquina e Inteligência Atificial;
# * Bibliotecas **Python**: **pandas, matplotlib**

# %% [markdown]
# ## Referências sobre a biblioteca **pandas** e **matplotlib**:
#
# *   [pandas](https://pandas.pydata.org/) é uma bilioteca para análise de dados em Python, de código aberto, licenciada pod BSD, utiliza o conceito de dataframes que funcionam como uma matriz de dados, formada por linhas e colunas.
#
# * Documentação da biblioteca [matplotlib](https://matplotlib.org/stable/index.html).
#
# * Ciência de Dados comReprodutibilidade usando Jupyter, disponível: [https://www.doi.org/]().
#
# * Introdução à Análise de Dados com Python e pandas, disponível em: [https://enucomp.com.br/2017/enucomp_anaisX_2017.pdf]()
#
# * Introdução à Análise Exploratória de Dados com Python, disponível em: [https://ercas2019.enucompi.com.br/doc/livro_de_minicursos_ercas_pi_2019.pdf]()

# %% [markdown]
# ## Bibliotecas Necessárias

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('Versão numpy -> %s' % np.__version__)
print('Versão pandas -> %s' % pd.__version__)
print('Versão seaborn -> %s' % sns.__version__)
# Out:
# Versão numpy -> 1.23.5
# Versão pandas -> 1.5.3
# Versão seaborn -> 0.12.2

# %%
import matplotlib

print('Versão matplotlib %s' % matplotlib.__version__)
# Out:
# Versão matplotlib 3.7.1

# %% [markdown]
# ## Elementos de Dados Estruturados
#
# Dados são uma coleção de objetos discretos, eventos e fatos na forma de números, texto, imagens, vídeos objetos, áudio eoutras entidades.
#
# Muitos desses dados não são estruturados: imagens são um conjunto de pixels, sendo que cada pixel contém informações de cor RGB (red, green, blue -- vermelhor, verde, azul); textos são sequências de palavras e caracteres, geralmente organizados em seções, subseções e assim por diante. A Análise Exploratória de Dados (AED) visa trabalhar essa torrentede dados brutos e transfomá-los em informação acionável.
#
# A organização dos dados coletados é **fundamental** para que não hajam erros de processamento e **perda** de informações.
#
# A **apresentação** dos dados **depende** do tipo de variável e daquilo que se quer **mostrar**.
#
# **Variáveis**
#
# A AED analisa **cada** variável, ou seja, qualquer característica associada a uma população, como peso, altura, sexo ou idade por exemplo.
#
# As variáveis podem assumir diferentes valores, que basicamente podem ser **separados** em:
#
#   * **Quantitativos** ou númericos.
#
#   * **Qualitativos** ou não númericos, ou categóricos.
#
# **As variáveis quantitativas ou númericas podem ser:**
#
#   * **Discretas**: assumem apenas valores inteiros: Ex.: números de irmãos, número de passageiros;
#
#   * **Conínuas**: assume qualquer valor no intervalo dos números reais. Ex.: peso, altura.
#
# **As variáveis qualitativas ou categóricas podem ser:**
#
#   * **Nominais**: quando as categorias não possuem uma ordem natural. Ex.: nomes, cores, sexo;
#
#   * **Ordinais**: quando as categorias podem ser ordenadas. Ex.: tamanho (pequeno, médio, grande), classe social (baixa, média, alta), grau de instrução (básico, médio, graduação, pós-graduação).
#
# A imagem abaixo resume os tipos de variáveis.
#
#
# ![teste](https://images.squarespace-cdn.com/content/v1/5a2a067e8dd04151f6e8250d/1590355846511-158TZXXUJQH0AKRSL0Q5/Captura+de+Tela+2020-05-23+%C3%A0s+13.37.32.png)
#
#
# **Covenção dos dados de entrada**:
#
#   * Os dados devem estar no formato de **matriz** (linha x coluna);
#
#   * Cada linha da matriz corresponde a **uma** unidade experimental (**elemento** da **população** ou **amostra** no qual observamos as variáveis/**colunas** da tabela);
#
#   * Cada **coluna** da matriz corresponde a uma **variável**;

# %% [markdown]
# ## Pandas

# %% [markdown]
# O pandas é uma biblioteca licenciada com código aberto que oferece estruturas de dados de alto desempenho e de fácil utilização voltado a análise de dados para a linguagem de programação Python.
#
#   * Transforma dados de entrada em uma tabela de dados
#   * Componentes chave
#
#       * Series (Séries)
#
#       * DataFrame

# %% [markdown]
# ### Séries (series)
#
#   * Objeto unidimensional do tipo array contendo dados e rótulos (labels) (ou índices), criado sobre o numpy.
#
#   * Se um índice não for informado explicitamente, Pandas cria um automaticamente (equivalente a `range (n)`, sendo N é o tamanho dos seus dados)
#
#   * O índice é usado para implementar buscas rápidas, alinhamento de dados e operações de junção (como join em SQL)
#
#   * Suporta índices hierárquicos, onde cada label é uma tupla
#
#   * Criando uma serie

# %%
my_series = pd.Series([10, 20, 30, 40, 50])
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# * Conteúdos podem ser acessados via um ou mais índices

# %%
my_series[2]
# Out:
# 30

# %%
my_series.index = ['A', 'B', 'C', 'D', 'E']
my_series
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
my_series['C']
# Out:
# 30

# %%
print(my_series['A'])
# Out:
# 10

# %%
print(my_series[['B', 'C']])
# Out:
# B    20
# C    30
# dtype: int64

# %% [markdown]
# * slicing funciona para índices númericos e nominais

# %%
print(my_series[0:2])
# Out:
# A    10
# B    20
# dtype: int64

# %%
print(my_series['B':'D'])
# Out:
# B    20
# C    30
# D    40
# dtype: int64

# %%
print(my_series['B':])
# Out:
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
print(my_series[:'C'])
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %% [markdown]
# * máscaras booleanas também podem ser usadas

# %%
my_series >= 30
# Out:
# A    False
# B    False
# C     True
# D     True
# E     True
# dtype: bool

# %%
mask = my_series >= 30

# %%
my_series[mask]
# Out:
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# * reindex
#
#     * modifica o valor do índice, adiciona valores faltantes ou preenche valores faltantes

# %%
s = pd.Series(range(4))
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
print('Original')
print(s)
# Out:
# Original
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
sn = s.reindex([4, 3, 2, 1, 0, 5])
print(sn)
# Out:
# 4    NaN
# 3    3.0
# 2    2.0
# 1    1.0
# 0    0.0
# 5    NaN
# dtype: float64

# %%
print('Método 1 de tratar valores faltantes')
sn_1 = s.reindex([4, 3, 2, 1, 0, 5], fill_value=-1)
sn_1
# Out:
# Método 1 de tratar valores faltantes
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64

# %%
print('Método 2 de tratar os valores faltantes')
sn_2 = s.reindex([4, 3, 2, 1, 0, 5], method='nearest')
sn_2
# Out:
# Método 2 de tratar os valores faltantes
# 4    3
# 3    3
# 2    2
# 1    1
# 0    0
# 5    3
# dtype: int64

# %% [markdown]
# * Operações aritméticas (realizada de acordo com o "match" dos índices)

# %%
print(sn_1)
print(sn_2)
# Out:
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64
# 4    3
# 3    3
# 2    2
# 1    1
# 0    0
# 5    3
# dtype: int64

# %%
print(sn_1 + sn_2)
# Out:
# 4    2
# 3    6
# 2    4
# 1    2
# 0    0
# 5    2
# dtype: int64

# %%
print(sn_1 * sn_2)
# Out:
# 4   -3
# 3    9
# 2    4
# 1    1
# 0    0
# 5   -3
# dtype: int64

# %% [markdown]
# * é possível organizar os elementos de uma série pelo índice ou pelos valores

# %%
print(sn_1)
# Out:
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64

# %%
print(sn_1.sort_index())
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4   -1
# 5   -1
# dtype: int64

# %%
print(sn_1.sort_values())
# Out:
# 4   -1
# 5   -1
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %% [markdown]
# * Hé muitos métodos implementados para operar nos valores. Alguns exemplos, são:
#
#     * unique()
#     * value_counts()
#     * isin()
#     * ...(muito mais na parte II, próxima aula)

# %%
new_series = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
print(new_series)
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
print(new_series.unique())
# Out:
# ['c' 'a' 'd' 'b']

# %%
print(new_series.value_counts())
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
print(new_series.isin(['b', 'd']))
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
dir(new_series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_binop',
#  '_can_hold_na',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_convert',
#  '_convert_dtypes',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_duplicated',
#  '_find_valid_index',
#  '_flags',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_index_resolvers',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_copy',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_item_cache',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_map_values',
#  '_maybe_update_cacher',
#  '_memory_usage',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_name',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_single',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_labels',
#  '_set_name',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take',
#  '_take_with_is_copy',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'interpolate',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'iteritems',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'std',
#  'str',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %% [markdown]
# ### DataFrames
#
# Dataframe é uma estrutura de dados tabular bidimensional e mutável em tamanho, potencialmente heterogênea, com eixos rotulados (linas e colunas).
#
#   * Possui índices de linhas e colunas
#
#   * Pode ser interpretado como um dicionário de Séries (cada série em uma linha) em que todas as Séries compartilham o mesmo conjunto de índices (os índices das colunas)
#
# Dataframes podem ser criados de muitas maneiras diferentes:
#
#   * **2-D NumPy array:** Uma matriz de dados, podendo passar os índices de linha e coluna
#
#   * **Dict of arrays, lists, or tuples:** Cada sequência se torna uma coluna. As sequ~encias devem ter o mesmo número de elementos
#
#   * **Dict of Series:** Cada séries se torna uma coluna. Índices de cada séries são unidos para formar o índice das linhas
#
#   * **Dict of dicts:** Cada dicionário se torna uma coluna. Chaves dos dicionários se unem para formar os índices das linhas
#
#   * **List of dicts or Series:** Cada item se torna uma linha no DataFrame. A união das chaves (para dicionário) ou índices (para Séries) gera o índice das colunas
#
#   * **List of lists or tuples:** Similar a uma matriz do numpy
#
#   * **DataFrame:** O índice do DataFrame é mantido a não ser que um novo seja fornecido
#
#   * **NumPy masked array:** matriz de dados em que valores falso se tornam NaN

# %%
data = {
    'Name': ['Fulano A', 'Fulano B', 'Beltrano A', 'Beltrano B', 'Sicrano A', 'Sicrano B'],
    'Age': [20, 21, 19, 28, 20, 22]
}

df = pd.DataFrame(data)
df
# Out:
#          Name  Age
# 0    Fulano A   20
# 1    Fulano B   21
# 2  Beltrano A   19
# 3  Beltrano B   28
# 4   Sicrano A   20
# 5   Sicrano B   22

# %% [markdown]
# **Atenção:** Duas funções são muito úteis para analisar rapidamente um novo DataFrame: df.head() e df.dtypes()

# %%
df.head()
# Out:
#          Name  Age
# 0    Fulano A   20
# 1    Fulano B   21
# 2  Beltrano A   19
# 3  Beltrano B   28
# 4   Sicrano A   20

# %%
df.head(2)
# Out:
#        Name  Age
# 0  Fulano A   20
# 1  Fulano B   21

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %% [markdown]
# #### Manipulando e Acessando Colunas
#
#   * Colunas podem ser acessadas;
#
#       * usando seus rótulos dentro de [ ]
#
#       * usando rótulos como atributo
#
#       * usando lista de rótulos dentro de [ ] (acessa várias colunas)

# %%
d = {
    'state': ['FL', 'FL', 'GA', 'GA', 'GA'],
    'year': [2010, 2011, 2008, 2010, 2011],
    'pop': [18.8, 19.1, 9.7, 9.7, 9.8]
}

new_df = pd.DataFrame(d)
new_df
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df['state']
# Out:
# 0    FL
# 1    FL
# 2    GA
# 3    GA
# 4    GA
# Name: state, dtype: object

# %%
new_df.state
# Out:
# 0    FL
# 1    FL
# 2    GA
# 3    GA
# 4    GA
# Name: state, dtype: object

# %%
new_df[['state', 'pop']]
# Out:
#   state   pop
# 0    FL  18.8
# 1    FL  19.1
# 2    GA   9.7
# 3    GA   9.7
# 4    GA   9.8

# %% [markdown]
# * Colunas podem ser criadas simplesmente criando um novo rótulo
#
# * Colunas podem ser removidas usando o método `drop` ou `del`

# %%
new_df['new_col'] = np.zeros(5)
new_df
# Out:
#   state  year   pop  new_col
# 0    FL  2010  18.8      0.0
# 1    FL  2011  19.1      0.0
# 2    GA  2008   9.7      0.0
# 3    GA  2010   9.7      0.0
# 4    GA  2011   9.8      0.0

# %%
new_df.drop(['new_col'], axis=1)
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df = new_df.drop(['new_col'], axis=1)
new_df
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df.drop(['pop'], axis=1, inplace=True)
new_df
# Out:
#   state  year
# 0    FL  2010
# 1    FL  2011
# 2    GA  2008
# 3    GA  2010
# 4    GA  2011

# %% [markdown]
# #### Manipulando e Acessando Linhas
#
#   * Linhas podem ser acessadas usando:
#
#     * iloc: manipula o DataFrame como uma matriz com índices inteiros, assim como no Numpy
#     * loc: seleciona linhas pelos rótulos (índices) ou por máscara booleana

# %%
dod = {
    'GA': {'result_1': 9.7, 'result_2': 9.7, 'result_3': 9.8, 'result_4': 9.2, 'result_5': 10.1, 'result_6': 9.3},
    'FL': {'result_2': 18.1, 'result_3': 19.1, 'result_1': 20.1, 'result_4': 19.2, 'result_5': 20.1, 'result_6': 19.3},
    'DR': {'result_2': 8.1, 'result_3': 9.1, 'result_1': 7.1, 'result_4': 9.2, 'result_5': 6.1, 'result_6': 9.3},
    'GH': {'result_2': 22.4, 'result_3': 21.4, 'result_1': 17.9, 'result_4': 23.4, 'result_5': 17.1, 'result_6': 23.5}
}

dod_df = pd.DataFrame(dod)
dod_df
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.iloc[5]
# Out:
# GA     9.3
# FL    19.3
# DR     9.3
# GH    23.5
# Name: result_6, dtype: float64

# %%
dod_df.iloc[1:3]
# Out:
#            GA    FL   DR    GH
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4

# %%
dod_df.iloc[:3]
# Out:
#            GA    FL   DR    GH
# result_1  9.7  20.1  7.1  17.9
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4

# %%
dod_df.iloc[3:]
# Out:
#             GA    FL   DR    GH
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.iloc[:4]
# Out:
#            GA    FL   DR    GH
# result_1  9.7  20.1  7.1  17.9
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.iloc[4:, 2:3]
# Out:
#            DR
# result_5  6.1
# result_6  9.3

# %%
dod_df.iloc[4:, 2:]
# Out:
#            DR    GH
# result_5  6.1  17.1
# result_6  9.3  23.5

# %%
dod_df.loc['result_3']
# Out:
# GA     9.8
# FL    19.1
# DR     9.1
# GH    21.4
# Name: result_3, dtype: float64

# %%
dod_df.loc['result_2':'result_4']
# Out:
#            GA    FL   DR    GH
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.loc[dod_df['GA'] == 9.2]
# Out:
#            GA    FL   DR    GH
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.loc[dod_df['GA'] >= 9.5]
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_5  10.1  20.1  6.1  17.1

# %%
dod_df.loc[(dod_df['GA'] >= 9.5) & (dod_df['DR'] < 8)]
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_5  10.1  20.1  6.1  17.1

# %% [markdown]
# * Assim como nas Séries, também é possível ordernar por índice, mas ao ordenar por valor é necessário definir a coluna

# %%
dod_df
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.sort_values('DR')
# Out:
#             GA    FL   DR    GH
# result_5  10.1  20.1  6.1  17.1
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.sort_values(['GA', 'DR'])
# Out:
#             GA    FL   DR    GH
# result_4   9.2  19.2  9.2  23.4
# result_6   9.3  19.3  9.3  23.5
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_5  10.1  20.1  6.1  17.1

# %% [markdown]
# **Atenção:** sort_values, gera uma cópia. Para modificar o DataFrame, deve-se passar o parâmetro `inplace = True`

# %%
dod_df.sort_values(['GA', 'DR'], inplace=True)

# %% [markdown]
# ## Carregando arquivos
#
# Pandas permite diversas maneiras de carregar arquivos:
#
#   * Arquivos de texto
#   * Dados estruturados (JSON, XML, HTML, CSV)
#   * Excel (depende das bibliotecas xlrd e openpyxl)
#   * Direto da base de dados
#       * pandas.io.sql (read_frame)

# %%
json_df = pd.read_json('/content/sample_data/anscombe.json')
json_df.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Series  44 non-null     object
#  1   X       44 non-null     int64
#  2   Y       44 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
iris_df = pd.read_csv('/content/iris.data')
iris_df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris_df = pd.read_csv(
    '/content/iris.data',
    names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
    )

iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Base de Dados
#
# ## Microdados do Enem 2021
#
# Os microdados do Enem são o menor nível de desagregação de dados recolhidos por meio do exame. Eles atendem a demanda por informações específicas ao disponibilizar as provas, os gabaritos, as informações sobre os itens, as notas e o questionário respondido pelos inscritos no Enem.
#
# Fonte: [https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem]()

# %% [markdown]
# ### Fontes de Dados
#
# [https://download.inep.gov.br/microdados/microdados_enem_2021.zip]()

# %% [markdown]
# ### Variáveis utilizadas
#
#   ## TP_FAIXA_ETARIA
# ----
#
# Faixa etária dos inscritos
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# 1             | Meno que 17 anos
# 2             | 17 anos
# 3             | 18 anos
# 4             | 19 anos
# 5             | 20 anos
# 6             | 21 anos
# 7             | 22 anos
# 8             | 23 anos
# 9             | 24 anos
# 10            | 25 anos
# 11            | Entre 26 e 30 anos
# 12            | Entre 31 e 35 anos
# 13            | Entre 36 e 40 anos
# 14            | Entre 41 e 45 anos
# 15            | Entre 46 e 50 anos
# 16            | Entre 54 e 55 anos
# 17            | Entre 56 e 60 anos
# 18            | Entre 61 e 65 anos
# 19            | Entre 66 e 70 anos
# 20            | Maior de 70 anos
#
# </br>
#
# ## TP_SEXO
# ---
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | M             | Masculino       |
# | F             | Feminino        |
#
# </br>
#
# ## TP_COR_RACA
# ---
# |**Categoria**  | **Descrição**            |
# |:-------------:|:------------------------:|
# | 0             | Não declarado            |
# | 1             | Branca                   |
# | 2             | Preta                    |
# | 3             | Parda                    |
# | 4             | Amarela                  |
# | 5             | Indígena                 |
# | 6             | Não dispõe da informação |
# </br>
#
# ## SG_UF_ESC
# ---
# Sigla da Unidade da Federação da escola
#
# &nbsp;
#
# ## TP_DEPENDENCIA_ADM_ESC
# ---
# Dependência administrativa (Escola)
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | 1             | Federal         |
# | 2             | Estadual        |
# | 3             | Municipal       |
# | 4             | Privada         |
#
# </br>
#
# ## NU_NOTA_CN
# ---
# Nota da prova de Ciências da Natureza
#
# &nbsp;
#
#
# ## NU_NOTA_CH
# ---
# Nota da prova de Ciências Humanas
#
# &nbsp;
#
# ## NU_NOTA_LC
# ---
# Nota da prova de Linguagens e Códigos
#
# &nbsp;
#
# ## NU_NOTA_MT
# ---
# Nota da prova Matemática
#
# &nbsp;
#
# ## NU_NOTA_READACAO
# ---
# Nota da prova de Redação
#
# &nbsp;
#
# ## Q006
# ---
# Renda mensal dos familiares dos inscritos
#
# |**Categoria**  | **Descrição**                      |
# |:-------------:|:----------------------------------:|
# | A             | Nenhuma Renda                      |
# | B             | Até R\$ 1.000,00                   |
# | C             | De R\$ 1.100,01 até R\$ 1.650,00   |
# | D             | De R\$ 1.650,01 até R\$ 2.200,00   |
# | E             | De R\$ 2.200,01 até R\$ 2.750,00   |
# | F             | De R\$ 2.750,01 até R\$ 3.300,00   |
# | G             | De R\$ 3.300,01 até R\$ 4.400,00   |
# | H             | De R\$ 4.400,01 até R\$ 5.500,00   |
# | I             | De R\$ 5.500,01 até R\$ 6.600,00   |
# | J             | De R\$ 6.600,01 até R\$ 7.7000,00  |
# | K             | De R\$ 7.700,01 até R\$ 8.800,00   |
# | L             | De R\$ 8.800,01 até R\$ 9.900,00   |
# | M             | De R\$ 9.900,01 até R\$ 11.000,00  |
# | N             | De R\$ 11.000,01 até R\$ 13.200,00 |
# | O             | De R\$ 13.200,01 até R\$ 16.500,00 |
# | P             | De R\$ 16.500,01 até R\$ 22.000,00 |
# | Q             | Acima de R$ 22.000,00              |
# </br>
#
# ## Q022
# ----
#
# Quantidade de telefones celulares na residência dos inscritos
#
# |**Categoria**  | **Descrição**       |
# |:-------------:|:-------------------:|
# | A             | Não                 |
# | B             | Sim, um             |
# | C             | Sim, dois           |
# | D             | Sim, três           |
# | E             | Sim, quatro ou mais |
# </br>
#
# ## Q024
# ----
#
# Quantidade de Computadores na residência dos inscritos
#
# |**Categoria**  | **Descrição**       |
# |:-------------:|:-------------------:|
# | A             | Não                 |
# | B             | Sim, um             |
# | C             | Sim, dois           |
# | D             | Sim, três           |
# | E             | Sim, quatro ou mais |
#
# </br>
#
# ## Q025
# ---
# Informação sobre acesso a internet na residência do inscrito
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | A             | Não             |
# | B             | Sim             |

# %%
enem_df = pd.read_csv('/content/MICRODADOS_ENEM_2021.csv', sep=';', encoding='latin-1')
enem_df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0  ...     A     A     A    B     A    A     B     A     B     B
# 1  ...     A     A     A    B     A    A     C     A     A     A
# 2  ...     B     A     A    B     A    A     C     B     B     B
# 3  ...     A     A     A    B     A    A     B     A     B     B
# 4  ...     B     A     A    B     A    B     E     A     B     B
#
# [5 rows x 76 columns]

# %%
enem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50894 entries, 0 to 50893
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            50894 non-null  int64
#  1   NU_ANO                  50894 non-null  int64
#  2   TP_FAIXA_ETARIA         50894 non-null  int64
#  3   TP_SEXO                 50894 non-null  object
#  4   TP_ESTADO_CIVIL         50894 non-null  int64
#  5   TP_COR_RACA             50894 non-null  int64
#  6   TP_NACIONALIDADE        50894 non-null  int64
#  7   TP_ST_CONCLUSAO         50894 non-null  int64
#  8   TP_ANO_CONCLUIU         50894 non-null  int64
#  9   TP_ESCOLA               50894 non-null  int64
#  10  TP_ENSINO               21649 non-null  float64
#  11  IN_TREINEIRO            50894 non-null  int64
#  12  CO_MUNICIPIO_ESC        13111 non-null  float64
#  13  NO_MUNICIPIO_ESC        13111 non-null  object
#  14  CO_UF_ESC               13111 non-null  float64
#  15  SG_UF_ESC               13111 non-null  object
#  16  TP_DEPENDENCIA_ADM_ESC  13111 non-null  float64
#  17  TP_LOCALIZACAO_ESC      13111 non-null  float64
#  18  TP_SIT_FUNC_ESC         13111 non-null  float64
#  19  CO_MUNICIPIO_PROVA      50894 non-null  int64
#  20  NO_MUNICIPIO_PROVA      50894 non-null  object
#  21  CO_UF_PROVA             50894 non-null  int64
#  22  SG_UF_PROVA             50894 non-null  object
#  23  TP_PRESENCA_CN          50894 non-null  int64
#  24  TP_PRESENCA_CH          50894 non-null  int64
#  25  TP_PRESENCA_LC          50894 non-null  int64
#  26  TP_PRESENCA_MT          50894 non-null  int64
#  27  CO_PROVA_CN             39853 non-null  float64
#  28  CO_PROVA_CH             41494 non-null  float64
#  29  CO_PROVA_LC             41494 non-null  float64
#  30  CO_PROVA_MT             39853 non-null  float64
#  31  NU_NOTA_CN              39853 non-null  float64
#  32  NU_NOTA_CH              41494 non-null  float64
#  33  NU_NOTA_LC              41494 non-null  float64
#  34  NU_NOTA_MT              39853 non-null  float64
#  35  TX_RESPOSTAS_CN         39853 non-null  object
#  36  TX_RESPOSTAS_CH         41494 non-null  object
#  37  TX_RESPOSTAS_LC         41494 non-null  object
#  38  TX_RESPOSTAS_MT         39853 non-null  object
#  39  TP_LINGUA               50894 non-null  int64
#  40  TX_GABARITO_CN          39853 non-null  object
#  41  TX_GABARITO_CH          41494 non-null  object
#  42  TX_GABARITO_LC          41494 non-null  object
#  43  TX_GABARITO_MT          39853 non-null  object
#  44  TP_STATUS_REDACAO       41494 non-null  float64
#  45  NU_NOTA_COMP1           41494 non-null  float64
#  46  NU_NOTA_COMP2           41494 non-null  float64
#  47  NU_NOTA_COMP3           41493 non-null  float64
#  48  NU_NOTA_COMP4           41493 non-null  float64
#  49  NU_NOTA_COMP5           41493 non-null  float64
#  50  NU_NOTA_REDACAO         41493 non-null  float64
#  51  Q001                    50893 non-null  object
#  52  Q002                    50893 non-null  object
#  53  Q003                    50893 non-null  object
#  54  Q004                    50893 non-null  object
#  55  Q005                    50893 non-null  float64
#  56  Q006                    50893 non-null  object
#  57  Q007                    50893 non-null  object
#  58  Q008                    50893 non-null  object
#  59  Q009                    50893 non-null  object
#  60  Q010                    50893 non-null  object
#  61  Q011                    50893 non-null  object
#  62  Q012                    50893 non-null  object
#  63  Q013                    50893 non-null  object
#  64  Q014                    50893 non-null  object
#  65  Q015                    50893 non-null  object
#  66  Q016                    50893 non-null  object
#  67  Q017                    50893 non-null  object
#  68  Q018                    50893 non-null  object
#  69  Q019                    50893 non-null  object
#  70  Q020                    50893 non-null  object
#  71  Q021                    50893 non-null  object
#  72  Q022                    50893 non-null  object
#  73  Q023                    50893 non-null  object
#  74  Q024                    50893 non-null  object
#  75  Q025                    50893 non-null  object
# dtypes: float64(22), int64(17), object(37)
# memory usage: 29.5+ MB

# %%
var = ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q006', 'Q022', 'Q024', 'Q025']

# %%
enem_df[var].head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025
# 0    B    B
# 1    A    A
# 2    B    B
# 3    B    B
# 4    B    B

# %%
enem_df = enem_df[var]
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025
# 0    B    B
# 1    A    A
# 2    B    B
# 3    B    B
# 4    B    B

# %% [markdown]
# ## Distribuição de frequência
# ---
# Uma distribuição de frequência é um método de agrupamento de dados em classes, ou intervalos, de tal forma que se possa determinar o número, ou a porcentagem (isto é, a frequência) de cada classe, podendo ser apresentada sob a forma gráfica ou tabular.
#
# O primeiro passo em um trabalho de análise é o conhecimento do comportamento das variáveis envolvidas no estudo.

# %%
# 1 - Precisamos estabelecer as classes ou intervalos de agrupamentos dos dados;
# 2 - Enquadrar os dados nas, mediamente contagem;
# 3 - Contar o número em cada classe;
# 4 - Por fim, apresentar os resultados em uma tabela ou gráfico.

# %% [markdown]
# ### Método 1

# %%
enem_df['TP_SEXO']
# Out:
# 0        F
# 1        M
# 2        F
# 3        M
# 4        F
#         ..
# 50889    M
# 50890    M
# 50891    M
# 50892    F
# 50893    F
# Name: TP_SEXO, Length: 50894, dtype: object

# %%
enem_df['TP_SEXO'].value_counts()
# Out:
# F    35794
# M    15100
# Name: TP_SEXO, dtype: int64

# %%
enem_df['TP_SEXO'].value_counts(normalize=True)
# Out:
# F    0.703305
# M    0.296695
# Name: TP_SEXO, dtype: float64

# %%
enem_df['TP_SEXO'].value_counts(normalize=True) * 100
# Out:
# F    70.330491
# M    29.669509
# Name: TP_SEXO, dtype: float64

# %%
frequencia = enem_df['TP_SEXO'].value_counts()
porcentagem = enem_df['TP_SEXO'].value_counts(normalize=True) * 100

# %%
distribuicao_frequencia_sexo = pd.DataFrame(
    {
        'Frrequencia': frequencia,
        'porcentagem': porcentagem
    }
)

distribuicao_frequencia_sexo
# Out:
#    Frrequencia  porcentagem
# F        35794    70.330491
# M        15100    29.669509

# %%
distribuicao_frequencia_sexo.rename(index={'F': 'Feminino', 'M': 'Masculino'}, inplace=True)
distribuicao_frequencia_sexo.rename_axis('Sexo', axis='columns', inplace=True)

# %%
distribuicao_frequencia_sexo
# Out:
# Sexo       Frrequencia  porcentagem
# Feminino         35794    70.330491
# Masculino        15100    29.669509

# %% [markdown]
# ### Método 2

# %% [markdown]
# [https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html]()

# %%
sexo = {'M': 'Masculino', 'F': 'Feminino'}
internet = {'A': 'Não', 'B': 'Sim'}

# %%
frequencia_internet_sexo = pd.crosstab(
    enem_df['TP_SEXO'],
    enem_df['Q025']
)

frequencia_internet_sexo
# Out:
# Q025        A      B
# TP_SEXO
# F        3853  31940
# M        1573  13527

# %%
frequencia_internet_sexo.rename(index=sexo, inplace=True)
frequencia_internet_sexo.rename(columns=internet, inplace=True)
frequencia_internet_sexo.rename_axis('Internet', axis='columns', inplace=True)
frequencia_internet_sexo.rename_axis('Sexo', axis='rows', inplace=True)

frequencia_internet_sexo
# Out:
# Internet    Não    Sim
# Sexo
# Feminino   3853  31940
# Masculino  1573  13527

# %% [markdown]
# ## Distribuição de frequências para variáveis quantitativas (classes personalizadas)

# %% [markdown]
# ### Passo 1 - Especificar os limites de cada classe
#
# Utilizar a sequinte classificação para a RENDA FAMILIAR:
# <p> <br />
#
# **A >** Acima de 20 SM
#
# **B >** De 10 a 20 SM
#
# **C >** De 4 a 10 SM
#
# **D >** De 2 a 4 SM
#
# **E >** Até 2 SM
#
# Onde **SM** é o valor do salário mínimo na época. Em nosso caso **R$ 1.1000,00** (2021):
#
# **A >** Acima de 22.000
#
# **B >** De 11.000 a 22.000
#
# **C >** De 4.400 a 11.000
#
# **D >** De 2.200 a 4.400
#
# **E >** Até 1.100

# %%
def mapear_renda_familiar(categoria_renda):
  if categoria_renda in ['A', 'B']:
    return 1_100
  elif categoria_renda in ['C', 'D', 'E', 'F', 'G']:
    return 4_400
  elif categoria_renda in ['H', 'I', 'J', 'K', 'L', 'M']:
    return 11_000
  elif categoria_renda in ['N', 'O', 'P']:
    return 22_000
  else:
    return 23_000

# %%
enem_df['Q006']
# Out:
# 0          D
# 1          B
# 2          C
# 3          B
# 4          C
#         ...
# 50889      B
# 50890      B
# 50891      F
# 50892      C
# 50893    NaN
# Name: Q006, Length: 50894, dtype: object

# %%
enem_df['Q006'].apply(mapear_renda_familiar)
# Out:
# 0         4400
# 1         1100
# 2         4400
# 3         1100
# 4         4400
#          ...
# 50889     1100
# 50890     1100
# 50891     4400
# 50892     4400
# 50893    23000
# Name: Q006, Length: 50894, dtype: int64

# %%
enem_df['renda_familiar'] = enem_df['Q006'].apply(mapear_renda_familiar)
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# 1    A    A            1100
# 2    B    B            4400
# 3    B    B            1100
# 4    B    B            4400

# %%
classes = [0, 2_200, 4_400, 11_000, 22_000, 23_000]

# %%
labels = ['E', 'D', 'C', 'B', 'A']

# %% [markdown]
# ### Passo - 2 Criar a tabela de frequências

# %% [markdown]
# [https://pandas.pydata.org/docs/reference/api/pandas.cut.html]()

# %%
pd.cut(
    x = enem_df['renda_familiar'],
    bins = classes,
    labels = labels,
    include_lowest=True
)
# Out:
# 0        D
# 1        E
# 2        D
# 3        E
# 4        D
#         ..
# 50889    E
# 50890    E
# 50891    D
# 50892    D
# 50893    A
# Name: renda_familiar, Length: 50894, dtype: category
# Categories (5, object): ['E' < 'D' < 'C' < 'B' < 'A']

# %%
pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    )
)
# Out:
# D    23766
# E    21145
# C     4445
# B     1082
# A      456
# Name: renda_familiar, dtype: int64

# %%
frequencia_renda_familiar = pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    )
)

frequencia_renda_familiar
# Out:
# D    23766
# E    21145
# C     4445
# B     1082
# A      456
# Name: renda_familiar, dtype: int64

# %%
porcentagem_renda_familiar = pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    ),
    normalize=True
) * 100

porcentagem_renda_familiar
# Out:
# D    46.697057
# E    41.547137
# C     8.733839
# B     2.125987
# A     0.895980
# Name: renda_familiar, dtype: float64

# %%
porcentagem_renda_familiar = round(pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    ),
    normalize=True
) * 100, 2)

porcentagem_renda_familiar
# Out:
# D    46.70
# E    41.55
# C     8.73
# B     2.13
# A     0.90
# Name: renda_familiar, dtype: float64

# %%
distribuicao_frequencia_renda_familiar = pd.DataFrame(
    {
        'Frequencia': frequencia_renda_familiar,
        'Porcentagem (%)': porcentagem_renda_familiar
    }
)

distribuicao_frequencia_renda_familiar
# Out:
#    Frequencia  Porcentagem (%)
# D       23766            46.70
# E       21145            41.55
# C        4445             8.73
# B        1082             2.13
# A         456             0.90

# %%
distribuicao_frequencia_renda_familiar.sort_index()
# Out:
#    Frequencia  Porcentagem (%)
# E       21145            41.55
# D       23766            46.70
# C        4445             8.73
# B        1082             2.13
# A         456             0.90

# %%
distribuicao_frequencia_renda_familiar.sort_index(ascending=False)
# Out:
#    Frequencia  Porcentagem (%)
# A         456             0.90
# B        1082             2.13
# C        4445             8.73
# D       23766            46.70
# E       21145            41.55

# %% [markdown]
# ## Distribuição de frequências para variáveis quantitativas (Classes de amplitude fixa)

# %% [markdown]
# ### Passo 1 - Definindo o número de calsses

# %% [markdown]
# #### Regra de Sturges
#
#
# $k = 1 + \frac{10}{3} \log_{10}(n)$

# %%
enem_df.shape
# Out:
# (50894, 15)

# %%
n = enem_df.shape[0]
n
# Out:
# 50894

# %%
k = 1 + (10 / 3) * np.log10(n)
k
# Out:
# 16.688888618235495

# %%
int(k)
# Out:
# 16

# %%
round(k)
# Out:
# 17

# %%
k = round(k)
k
# Out:
# 17

# %% [markdown]
# ### Passo - 2 Craiar a tabela de frequências

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 50889    663.4
# 50890      NaN
# 50891    692.9
# 50892    480.3
# 50893    603.0
# Name: NU_NOTA_MT, Length: 50894, dtype: float64

# %%
frequencia_nota_matematica = pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
      bins = k,
      include_lowest=True
)
    )

frequencia_nota_matematica
# Out:
# (392.453, 448.518]    8561
# (448.518, 504.582]    8233
# (504.582, 560.647]    6186
# (560.647, 616.712]    5008
# (616.712, 672.776]    4156
# (672.776, 728.841]    2885
# (336.388, 392.453]    2192
# (728.841, 784.906]    1667
# (784.906, 840.971]     709
# (840.971, 897.035]     199
# (897.035, 953.1]        50
# (-0.954, 56.065]         6
# (280.324, 336.388]       1
# (56.065, 112.129]        0
# (224.259, 280.324]       0
# (168.194, 224.259]       0
# (112.129, 168.194]       0
# Name: NU_NOTA_MT, dtype: int64

# %%
porcentagem_nota_matematica = pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
        bins = k,
        include_lowest=True
    ),
    normalize=True
)

porcentagem_nota_matematica
# Out:
# (392.453, 448.518]    0.214814
# (448.518, 504.582]    0.206584
# (504.582, 560.647]    0.155220
# (560.647, 616.712]    0.125662
# (616.712, 672.776]    0.104283
# (672.776, 728.841]    0.072391
# (336.388, 392.453]    0.055002
# (728.841, 784.906]    0.041829
# (784.906, 840.971]    0.017790
# (840.971, 897.035]    0.004993
# (897.035, 953.1]      0.001255
# (-0.954, 56.065]      0.000151
# (280.324, 336.388]    0.000025
# (56.065, 112.129]     0.000000
# (224.259, 280.324]    0.000000
# (168.194, 224.259]    0.000000
# (112.129, 168.194]    0.000000
# Name: NU_NOTA_MT, dtype: float64

# %%
porcentagem_nota_matematica = round(pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
        bins = k,
        include_lowest=True
    ),
    normalize=True
), 2)

porcentagem_nota_matematica
# Out:
# (392.453, 448.518]    0.21
# (448.518, 504.582]    0.21
# (504.582, 560.647]    0.16
# (560.647, 616.712]    0.13
# (616.712, 672.776]    0.10
# (672.776, 728.841]    0.07
# (336.388, 392.453]    0.06
# (728.841, 784.906]    0.04
# (784.906, 840.971]    0.02
# (840.971, 897.035]    0.00
# (897.035, 953.1]      0.00
# (-0.954, 56.065]      0.00
# (280.324, 336.388]    0.00
# (56.065, 112.129]     0.00
# (224.259, 280.324]    0.00
# (168.194, 224.259]    0.00
# (112.129, 168.194]    0.00
# Name: NU_NOTA_MT, dtype: float64

# %%
distribuicao_frequencia_nota_matematica = pd.DataFrame(
    {
        'Frequencia': frequencia_nota_matematica,
        'Porcentagem (%)': porcentagem_nota_matematica
    }
)

distribuicao_frequencia_nota_matematica
# Out:
#                     Frequencia  Porcentagem (%)
# (392.453, 448.518]        8561             0.21
# (448.518, 504.582]        8233             0.21
# (504.582, 560.647]        6186             0.16
# (560.647, 616.712]        5008             0.13
# (616.712, 672.776]        4156             0.10
# (672.776, 728.841]        2885             0.07
# (336.388, 392.453]        2192             0.06
# (728.841, 784.906]        1667             0.04
# (784.906, 840.971]         709             0.02
# (840.971, 897.035]         199             0.00
# (897.035, 953.1]            50             0.00
# (-0.954, 56.065]             6             0.00
# (280.324, 336.388]           1             0.00
# (56.065, 112.129]            0             0.00
# (224.259, 280.324]           0             0.00
# (168.194, 224.259]           0             0.00
# (112.129, 168.194]           0             0.00

# %% [markdown]
# ## Histograma
# ---
# O **HISTOGRAMA** é a representação gráfica de uma distribuição de frequências. É um gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à fequência da classe que ele representa.

# %%
distribuicao_frequencia_nota_matematica
# Out:
#                     Frequencia  Porcentagem (%)
# (392.453, 448.518]        8561             0.21
# (448.518, 504.582]        8233             0.21
# (504.582, 560.647]        6186             0.16
# (560.647, 616.712]        5008             0.13
# (616.712, 672.776]        4156             0.10
# (672.776, 728.841]        2885             0.07
# (336.388, 392.453]        2192             0.06
# (728.841, 784.906]        1667             0.04
# (784.906, 840.971]         709             0.02
# (840.971, 897.035]         199             0.00
# (897.035, 953.1]            50             0.00
# (-0.954, 56.065]             6             0.00
# (280.324, 336.388]           1             0.00
# (56.065, 112.129]            0             0.00
# (224.259, 280.324]           0             0.00
# (168.194, 224.259]           0             0.00
# (112.129, 168.194]           0             0.00

# %%
distribuicao_frequencia_nota_matematica['Frequencia'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(distribuicao_frequencia_nota_matematica['Frequencia'])
# Out:
# <Axes: xlabel='Frequencia', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'])
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'], bins=100)
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'], bins=100, kde=True)
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %% [markdown]
# ## **Medidas Estatísticas**
#
# * As **medidas de tendência** central mostram o valor representativo em torno do qual os dados tendem a agrupar-se,
#
# * As **medidas de dispersão** mostram o grau de afastamento dos valores observados em relação ao ponto central da
#
# * As **medidas de posição relativa** mostram pontos de corte na distribuição relativa dos dados da amostra.

# %% [markdown]
# ### Medidas de Tendência Central
#
# As medidas de tendência ou "de posição" procuram caracterizar a tendência do conjunto (valor "típico") a um valor numérico que "represente" o conjunto. Esse valor pode ser calculado levando em conta todos os valores do conjunto ou apenas alguns valores ordenados.

# %% [markdown]
# #### Média
#
# A média aritmética simples é a soma dos valores observados dividida pelo número desses valores, definida da seguinte forma:
#
# ![](https://arquivos.respondeai.com.br/seo/2023/aedc5b6d-bd3b-49b6-b780-53ad3f6087ff.webp)
#
#
# * Existem duas formas de se calcular a média.

# %%
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# 1    A    A            1100
# 2    B    B            4400
# 3    B    B            1100
# 4    B    B            4400

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 50889    663.4
# 50890      NaN
# 50891    692.9
# 50892    480.3
# 50893    603.0
# Name: NU_NOTA_MT, Length: 50894, dtype: float64

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / len(enem_df['NU_NOTA_MT'])
nota_matematica_01
# Out:
# 418.96846779581097

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / enem_df['NU_NOTA_MT'].shape[0]
nota_matematica_01
# Out:
# 418.96846779581097

# %%
enem_df['NU_NOTA_MT'].mean()
# Out:
# 535.0408049582215

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 50889    663.4
# 50890      NaN
# 50891    692.9
# 50892    480.3
# 50893    603.0
# Name: NU_NOTA_MT, Length: 50894, dtype: float64

# %%
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# 1    A    A            1100
# 2    B    B            4400
# 3    B    B            1100
# 4    B    B            4400

# %%
print(f"Antes: {enem_df.shape}")
# Out:
# Antes: (50894, 15)

# %%
# Retirando os valores faltantes na base de dados

enem_df.dropna(inplace=True)

# %%
print(f"Agora: {enem_df.shape}")
# Out:
# Agora: (11179, 15)

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3       M            3        CE                     2.0
# 4                 2       F            3        CE                     2.0
# 33                3       M            1        BA                     2.0
# 45                4       F            3        ES                     1.0
# 51                3       M            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# 3     B    B            1100
# 4     B    B            4400
# 33    B    B            1100
# 45    A    B            4400
# 51    B    B            4400

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / len(enem_df['NU_NOTA_MT'])
nota_matematica_01
# Out:
# 545.3430718311118

# %%
nota_matematica_02 = enem_df['NU_NOTA_MT'].mean()
nota_matematica_02
# Out:
# 545.3430718311118

# %% [markdown]
# #### Medianda
#
# A mediana é o valor médio ou a média aritmética de dois valores centrais de um conjunto de números ordenados (crescente
