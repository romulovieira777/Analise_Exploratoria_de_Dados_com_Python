# %% [markdown]
# ## Análise Exploratoria de Dados

# %% [markdown]
# # Ferramentas e Bibliotecas

# %% [markdown]
# *   [Google Colab](https://colab.google/): Serviço de nuvem gratuito hospedado pelo Google para incentivar a pesquisa de Aprendizado de Máquina e Inteligência Atificial;
# * Bibliotecas **Python**: **pandas, matplotlib**

# %% [markdown]
# ## Referências sobre a biblioteca **pandas** e **matplotlib**:
#
# *   [pandas](https://pandas.pydata.org/) é uma bilioteca para análise de dados em Python, de código aberto, licenciada pod BSD, utiliza o conceito de dataframes que funcionam como uma matriz de dados, formada por linhas e colunas.
#
# * Documentação da biblioteca [matplotlib](https://matplotlib.org/stable/index.html).
#
# * Ciência de Dados comReprodutibilidade usando Jupyter, disponível: [https://www.doi.org/]().
#
# * Introdução à Análise de Dados com Python e pandas, disponível em: [https://enucomp.com.br/2017/enucomp_anaisX_2017.pdf]()
#
# * Introdução à Análise Exploratória de Dados com Python, disponível em: [https://ercas2019.enucompi.com.br/doc/livro_de_minicursos_ercas_pi_2019.pdf]()

# %% [markdown]
# ## Bibliotecas Necessárias

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('Versão numpy -> %s' % np.__version__)
print('Versão pandas -> %s' % pd.__version__)
print('Versão seaborn -> %s' % sns.__version__)
# Out:
# Versão numpy -> 1.23.5
# Versão pandas -> 1.5.3
# Versão seaborn -> 0.12.2

# %%
import matplotlib

print('Versão matplotlib %s' % matplotlib.__version__)
# Out:
# Versão matplotlib 3.7.1

# %% [markdown]
# ## Elementos de Dados Estruturados
#
# Dados são uma coleção de objetos discretos, eventos e fatos na forma de números, texto, imagens, vídeos objetos, áudio eoutras entidades.
#
# Muitos desses dados não são estruturados: imagens são um conjunto de pixels, sendo que cada pixel contém informações de cor RGB (red, green, blue -- vermelhor, verde, azul); textos são sequências de palavras e caracteres, geralmente organizados em seções, subseções e assim por diante. A Análise Exploratória de Dados (AED) visa trabalhar essa torrentede dados brutos e transfomá-los em informação acionável.
#
# A organização dos dados coletados é **fundamental** para que não hajam erros de processamento e **perda** de informações.
#
# A **apresentação** dos dados **depende** do tipo de variável e daquilo que se quer **mostrar**.
#
# **Variáveis**
#
# A AED analisa **cada** variável, ou seja, qualquer característica associada a uma população, como peso, altura, sexo ou idade por exemplo.
#
# As variáveis podem assumir diferentes valores, que basicamente podem ser **separados** em:
#
#   * **Quantitativos** ou númericos.
#
#   * **Qualitativos** ou não númericos, ou categóricos.
#
# **As variáveis quantitativas ou númericas podem ser:**
#
#   * **Discretas**: assumem apenas valores inteiros: Ex.: números de irmãos, número de passageiros;
#
#   * **Conínuas**: assume qualquer valor no intervalo dos números reais. Ex.: peso, altura.
#
# **As variáveis qualitativas ou categóricas podem ser:**
#
#   * **Nominais**: quando as categorias não possuem uma ordem natural. Ex.: nomes, cores, sexo;
#
#   * **Ordinais**: quando as categorias podem ser ordenadas. Ex.: tamanho (pequeno, médio, grande), classe social (baixa, média, alta), grau de instrução (básico, médio, graduação, pós-graduação).
#
# A imagem abaixo resume os tipos de variáveis.
#
#
# ![teste](https://images.squarespace-cdn.com/content/v1/5a2a067e8dd04151f6e8250d/1590355846511-158TZXXUJQH0AKRSL0Q5/Captura+de+Tela+2020-05-23+%C3%A0s+13.37.32.png)
#
#
# **Covenção dos dados de entrada**:
#
#   * Os dados devem estar no formato de **matriz** (linha x coluna);
#
#   * Cada linha da matriz corresponde a **uma** unidade experimental (**elemento** da **população** ou **amostra** no qual observamos as variáveis/**colunas** da tabela);
#
#   * Cada **coluna** da matriz corresponde a uma **variável**;

# %% [markdown]
# ## Pandas

# %% [markdown]
# O pandas é uma biblioteca licenciada com código aberto que oferece estruturas de dados de alto desempenho e de fácil utilização voltado a análise de dados para a linguagem de programação Python.
#
#   * Transforma dados de entrada em uma tabela de dados
#   * Componentes chave
#
#       * Series (Séries)
#
#       * DataFrame

# %% [markdown]
# ### Séries (series)
#
#   * Objeto unidimensional do tipo array contendo dados e rótulos (labels) (ou índices), criado sobre o numpy.
#
#   * Se um índice não for informado explicitamente, Pandas cria um automaticamente (equivalente a `range (n)`, sendo N é o tamanho dos seus dados)
#
#   * O índice é usado para implementar buscas rápidas, alinhamento de dados e operações de junção (como join em SQL)
#
#   * Suporta índices hierárquicos, onde cada label é uma tupla
#
#   * Criando uma serie

# %%
my_series = pd.Series([10, 20, 30, 40, 50])
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# * Conteúdos podem ser acessados via um ou mais índices

# %%
my_series[2]
# Out:
# 30

# %%
my_series.index = ['A', 'B', 'C', 'D', 'E']
my_series
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
my_series['C']
# Out:
# 30

# %%
print(my_series['A'])
# Out:
# 10

# %%
print(my_series[['B', 'C']])
# Out:
# B    20
# C    30
# dtype: int64

# %% [markdown]
# * slicing funciona para índices númericos e nominais

# %%
print(my_series[0:2])
# Out:
# A    10
# B    20
# dtype: int64

# %%
print(my_series['B':'D'])
# Out:
# B    20
# C    30
# D    40
# dtype: int64

# %%
print(my_series['B':])
# Out:
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
print(my_series[:'C'])
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %% [markdown]
# * máscaras booleanas também podem ser usadas

# %%
my_series >= 30
# Out:
# A    False
# B    False
# C     True
# D     True
# E     True
# dtype: bool

# %%
mask = my_series >= 30

# %%
my_series[mask]
# Out:
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# * reindex
#
#     * modifica o valor do índice, adiciona valores faltantes ou preenche valores faltantes

# %%
s = pd.Series(range(4))
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
print('Original')
print(s)
# Out:
# Original
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
sn = s.reindex([4, 3, 2, 1, 0, 5])
print(sn)
# Out:
# 4    NaN
# 3    3.0
# 2    2.0
# 1    1.0
# 0    0.0
# 5    NaN
# dtype: float64

# %%
print('Método 1 de tratar valores faltantes')
sn_1 = s.reindex([4, 3, 2, 1, 0, 5], fill_value=-1)
sn_1
# Out:
# Método 1 de tratar valores faltantes
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64

# %%
print('Método 2 de tratar os valores faltantes')
sn_2 = s.reindex([4, 3, 2, 1, 0, 5], method='nearest')
sn_2
# Out:
# Método 2 de tratar os valores faltantes
# 4    3
# 3    3
# 2    2
# 1    1
# 0    0
# 5    3
# dtype: int64

# %% [markdown]
# * Operações aritméticas (realizada de acordo com o "match" dos índices)

# %%
print(sn_1)
print(sn_2)
# Out:
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64
# 4    3
# 3    3
# 2    2
# 1    1
# 0    0
# 5    3
# dtype: int64

# %%
print(sn_1 + sn_2)
# Out:
# 4    2
# 3    6
# 2    4
# 1    2
# 0    0
# 5    2
# dtype: int64

# %%
print(sn_1 * sn_2)
# Out:
# 4   -3
# 3    9
# 2    4
# 1    1
# 0    0
# 5   -3
# dtype: int64

# %% [markdown]
# * é possível organizar os elementos de uma série pelo índice ou pelos valores

# %%
print(sn_1)
# Out:
# 4   -1
# 3    3
# 2    2
# 1    1
# 0    0
# 5   -1
# dtype: int64

# %%
print(sn_1.sort_index())
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4   -1
# 5   -1
# dtype: int64

# %%
print(sn_1.sort_values())
# Out:
# 4   -1
# 5   -1
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %% [markdown]
# * Hé muitos métodos implementados para operar nos valores. Alguns exemplos, são:
#
#     * unique()
#     * value_counts()
#     * isin()
#     * ...(muito mais na parte II, próxima aula)

# %%
new_series = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
print(new_series)
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
print(new_series.unique())
# Out:
# ['c' 'a' 'd' 'b']

# %%
print(new_series.value_counts())
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
print(new_series.isin(['b', 'd']))
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
dir(new_series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %% [markdown]
# ### DataFrames
#
# Dataframe é uma estrutura de dados tabular bidimensional e mutável em tamanho, potencialmente heterogênea, com eixos rotulados (linas e colunas).
#
#   * Possui índices de linhas e colunas
#
#   * Pode ser interpretado como um dicionário de Séries (cada série em uma linha) em que todas as Séries compartilham o mesmo conjunto de índices (os índices das colunas)
#
# Dataframes podem ser criados de muitas maneiras diferentes:
#
#   * **2-D NumPy array:** Uma matriz de dados, podendo passar os índices de linha e coluna
#
#   * **Dict of arrays, lists, or tuples:** Cada sequência se torna uma coluna. As sequ~encias devem ter o mesmo número de elementos
#
#   * **Dict of Series:** Cada séries se torna uma coluna. Índices de cada séries são unidos para formar o índice das linhas
#
#   * **Dict of dicts:** Cada dicionário se torna uma coluna. Chaves dos dicionários se unem para formar os índices das linhas
#
#   * **List of dicts or Series:** Cada item se torna uma linha no DataFrame. A união das chaves (para dicionário) ou índices (para Séries) gera o índice das colunas
#
#   * **List of lists or tuples:** Similar a uma matriz do numpy
#
#   * **DataFrame:** O índice do DataFrame é mantido a não ser que um novo seja fornecido
#
#   * **NumPy masked array:** matriz de dados em que valores falso se tornam NaN

# %%
data = {
    'Name': ['Fulano A', 'Fulano B', 'Beltrano A', 'Beltrano B', 'Sicrano A', 'Sicrano B'],
    'Age': [20, 21, 19, 28, 20, 22]
}

df = pd.DataFrame(data)
df
# Out:
#          Name  Age
# 0    Fulano A   20
# 1    Fulano B   21
# 2  Beltrano A   19
# 3  Beltrano B   28
# 4   Sicrano A   20
# 5   Sicrano B   22

# %% [markdown]
# **Atenção:** Duas funções são muito úteis para analisar rapidamente um novo DataFrame: df.head() e df.dtypes()

# %%
df.head()
# Out:
#          Name  Age
# 0    Fulano A   20
# 1    Fulano B   21
# 2  Beltrano A   19
# 3  Beltrano B   28
# 4   Sicrano A   20

# %%
df.head(2)
# Out:
#        Name  Age
# 0  Fulano A   20
# 1  Fulano B   21

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %% [markdown]
# #### Manipulando e Acessando Colunas
#
#   * Colunas podem ser acessadas;
#
#       * usando seus rótulos dentro de [ ]
#
#       * usando rótulos como atributo
#
#       * usando lista de rótulos dentro de [ ] (acessa várias colunas)

# %%
d = {
    'state': ['FL', 'FL', 'GA', 'GA', 'GA'],
    'year': [2010, 2011, 2008, 2010, 2011],
    'pop': [18.8, 19.1, 9.7, 9.7, 9.8]
}

new_df = pd.DataFrame(d)
new_df
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df['state']
# Out:
# 0    FL
# 1    FL
# 2    GA
# 3    GA
# 4    GA
# Name: state, dtype: object

# %%
new_df.state
# Out:
# 0    FL
# 1    FL
# 2    GA
# 3    GA
# 4    GA
# Name: state, dtype: object

# %%
new_df[['state', 'pop']]
# Out:
#   state   pop
# 0    FL  18.8
# 1    FL  19.1
# 2    GA   9.7
# 3    GA   9.7
# 4    GA   9.8

# %% [markdown]
# * Colunas podem ser criadas simplesmente criando um novo rótulo
#
# * Colunas podem ser removidas usando o método `drop` ou `del`

# %%
new_df['new_col'] = np.zeros(5)
new_df
# Out:
#   state  year   pop  new_col
# 0    FL  2010  18.8      0.0
# 1    FL  2011  19.1      0.0
# 2    GA  2008   9.7      0.0
# 3    GA  2010   9.7      0.0
# 4    GA  2011   9.8      0.0

# %%
new_df.drop(['new_col'], axis=1)
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df = new_df.drop(['new_col'], axis=1)
new_df
# Out:
#   state  year   pop
# 0    FL  2010  18.8
# 1    FL  2011  19.1
# 2    GA  2008   9.7
# 3    GA  2010   9.7
# 4    GA  2011   9.8

# %%
new_df.drop(['pop'], axis=1, inplace=True)
new_df
# Out:
#   state  year
# 0    FL  2010
# 1    FL  2011
# 2    GA  2008
# 3    GA  2010
# 4    GA  2011

# %% [markdown]
# #### Manipulando e Acessando Linhas
#
#   * Linhas podem ser acessadas usando:
#
#     * iloc: manipula o DataFrame como uma matriz com índices inteiros, assim como no Numpy
#     * loc: seleciona linhas pelos rótulos (índices) ou por máscara booleana

# %%
dod = {
    'GA': {'result_1': 9.7, 'result_2': 9.7, 'result_3': 9.8, 'result_4': 9.2, 'result_5': 10.1, 'result_6': 9.3},
    'FL': {'result_2': 18.1, 'result_3': 19.1, 'result_1': 20.1, 'result_4': 19.2, 'result_5': 20.1, 'result_6': 19.3},
    'DR': {'result_2': 8.1, 'result_3': 9.1, 'result_1': 7.1, 'result_4': 9.2, 'result_5': 6.1, 'result_6': 9.3},
    'GH': {'result_2': 22.4, 'result_3': 21.4, 'result_1': 17.9, 'result_4': 23.4, 'result_5': 17.1, 'result_6': 23.5}
}

dod_df = pd.DataFrame(dod)
dod_df
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.iloc[5]
# Out:
# GA     9.3
# FL    19.3
# DR     9.3
# GH    23.5
# Name: result_6, dtype: float64

# %%
dod_df.iloc[1:3]
# Out:
#            GA    FL   DR    GH
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4

# %%
dod_df.iloc[:3]
# Out:
#            GA    FL   DR    GH
# result_1  9.7  20.1  7.1  17.9
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4

# %%
dod_df.iloc[3:]
# Out:
#             GA    FL   DR    GH
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.iloc[:4]
# Out:
#            GA    FL   DR    GH
# result_1  9.7  20.1  7.1  17.9
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.iloc[4:, 2:3]
# Out:
#            DR
# result_5  6.1
# result_6  9.3

# %%
dod_df.iloc[4:, 2:]
# Out:
#            DR    GH
# result_5  6.1  17.1
# result_6  9.3  23.5

# %%
dod_df.loc['result_3']
# Out:
# GA     9.8
# FL    19.1
# DR     9.1
# GH    21.4
# Name: result_3, dtype: float64

# %%
dod_df.loc['result_2':'result_4']
# Out:
#            GA    FL   DR    GH
# result_2  9.7  18.1  8.1  22.4
# result_3  9.8  19.1  9.1  21.4
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.loc[dod_df['GA'] == 9.2]
# Out:
#            GA    FL   DR    GH
# result_4  9.2  19.2  9.2  23.4

# %%
dod_df.loc[dod_df['GA'] >= 9.5]
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_5  10.1  20.1  6.1  17.1

# %%
dod_df.loc[(dod_df['GA'] >= 9.5) & (dod_df['DR'] < 8)]
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_5  10.1  20.1  6.1  17.1

# %% [markdown]
# * Assim como nas Séries, também é possível ordernar por índice, mas ao ordenar por valor é necessário definir a coluna

# %%
dod_df
# Out:
#             GA    FL   DR    GH
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_5  10.1  20.1  6.1  17.1
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.sort_values('DR')
# Out:
#             GA    FL   DR    GH
# result_5  10.1  20.1  6.1  17.1
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_4   9.2  19.2  9.2  23.4
# result_6   9.3  19.3  9.3  23.5

# %%
dod_df.sort_values(['GA', 'DR'])
# Out:
#             GA    FL   DR    GH
# result_4   9.2  19.2  9.2  23.4
# result_6   9.3  19.3  9.3  23.5
# result_1   9.7  20.1  7.1  17.9
# result_2   9.7  18.1  8.1  22.4
# result_3   9.8  19.1  9.1  21.4
# result_5  10.1  20.1  6.1  17.1

# %% [markdown]
# **Atenção:** sort_values, gera uma cópia. Para modificar o DataFrame, deve-se passar o parâmetro `inplace = True`

# %%
dod_df.sort_values(['GA', 'DR'], inplace=True)

# %% [markdown]
# ## Carregando arquivos
#
# Pandas permite diversas maneiras de carregar arquivos:
#
#   * Arquivos de texto
#   * Dados estruturados (JSON, XML, HTML, CSV)
#   * Excel (depende das bibliotecas xlrd e openpyxl)
#   * Direto da base de dados
#       * pandas.io.sql (read_frame)

# %%
json_df = pd.read_json('/content/sample_data/anscombe.json')
json_df.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Series  44 non-null     object
#  1   X       44 non-null     int64
#  2   Y       44 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
iris_df = pd.read_csv('/content/iris.data')
iris_df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris_df = pd.read_csv(
    '/content/iris.data',
    names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
    )

iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Base de Dados
#
# ## Microdados do Enem 2021
#
# Os microdados do Enem são o menor nível de desagregação de dados recolhidos por meio do exame. Eles atendem a demanda por informações específicas ao disponibilizar as provas, os gabaritos, as informações sobre os itens, as notas e o questionário respondido pelos inscritos no Enem.
#
# Fonte: [https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem]()

# %% [markdown]
# ### Fontes de Dados
#
# [https://download.inep.gov.br/microdados/microdados_enem_2021.zip]()

# %% [markdown]
# ### Variáveis utilizadas
#
#   ## TP_FAIXA_ETARIA
# ----
#
# Faixa etária dos inscritos
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# 1             | Meno que 17 anos
# 2             | 17 anos
# 3             | 18 anos
# 4             | 19 anos
# 5             | 20 anos
# 6             | 21 anos
# 7             | 22 anos
# 8             | 23 anos
# 9             | 24 anos
# 10            | 25 anos
# 11            | Entre 26 e 30 anos
# 12            | Entre 31 e 35 anos
# 13            | Entre 36 e 40 anos
# 14            | Entre 41 e 45 anos
# 15            | Entre 46 e 50 anos
# 16            | Entre 54 e 55 anos
# 17            | Entre 56 e 60 anos
# 18            | Entre 61 e 65 anos
# 19            | Entre 66 e 70 anos
# 20            | Maior de 70 anos
#
# </br>
#
# ## TP_SEXO
# ---
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | M             | Masculino       |
# | F             | Feminino        |
#
# </br>
#
# ## TP_COR_RACA
# ---
# |**Categoria**  | **Descrição**            |
# |:-------------:|:------------------------:|
# | 0             | Não declarado            |
# | 1             | Branca                   |
# | 2             | Preta                    |
# | 3             | Parda                    |
# | 4             | Amarela                  |
# | 5             | Indígena                 |
# | 6             | Não dispõe da informação |
# </br>
#
# ## SG_UF_ESC
# ---
# Sigla da Unidade da Federação da escola
#
# &nbsp;
#
# ## TP_DEPENDENCIA_ADM_ESC
# ---
# Dependência administrativa (Escola)
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | 1             | Federal         |
# | 2             | Estadual        |
# | 3             | Municipal       |
# | 4             | Privada         |
#
# </br>
#
# ## NU_NOTA_CN
# ---
# Nota da prova de Ciências da Natureza
#
# &nbsp;
#
#
# ## NU_NOTA_CH
# ---
# Nota da prova de Ciências Humanas
#
# &nbsp;
#
# ## NU_NOTA_LC
# ---
# Nota da prova de Linguagens e Códigos
#
# &nbsp;
#
# ## NU_NOTA_MT
# ---
# Nota da prova Matemática
#
# &nbsp;
#
# ## NU_NOTA_READACAO
# ---
# Nota da prova de Redação
#
# &nbsp;
#
# ## Q006
# ---
# Renda mensal dos familiares dos inscritos
#
# |**Categoria**  | **Descrição**                      |
# |:-------------:|:----------------------------------:|
# | A             | Nenhuma Renda                      |
# | B             | Até R\$ 1.000,00                   |
# | C             | De R\$ 1.100,01 até R\$ 1.650,00   |
# | D             | De R\$ 1.650,01 até R\$ 2.200,00   |
# | E             | De R\$ 2.200,01 até R\$ 2.750,00   |
# | F             | De R\$ 2.750,01 até R\$ 3.300,00   |
# | G             | De R\$ 3.300,01 até R\$ 4.400,00   |
# | H             | De R\$ 4.400,01 até R\$ 5.500,00   |
# | I             | De R\$ 5.500,01 até R\$ 6.600,00   |
# | J             | De R\$ 6.600,01 até R\$ 7.7000,00  |
# | K             | De R\$ 7.700,01 até R\$ 8.800,00   |
# | L             | De R\$ 8.800,01 até R\$ 9.900,00   |
# | M             | De R\$ 9.900,01 até R\$ 11.000,00  |
# | N             | De R\$ 11.000,01 até R\$ 13.200,00 |
# | O             | De R\$ 13.200,01 até R\$ 16.500,00 |
# | P             | De R\$ 16.500,01 até R\$ 22.000,00 |
# | Q             | Acima de R$ 22.000,00              |
# </br>
#
# ## Q022
# ----
#
# Quantidade de telefones celulares na residência dos inscritos
#
# |**Categoria**  | **Descrição**       |
# |:-------------:|:-------------------:|
# | A             | Não                 |
# | B             | Sim, um             |
# | C             | Sim, dois           |
# | D             | Sim, três           |
# | E             | Sim, quatro ou mais |
# </br>
#
# ## Q024
# ----
#
# Quantidade de Computadores na residência dos inscritos
#
# |**Categoria**  | **Descrição**       |
# |:-------------:|:-------------------:|
# | A             | Não                 |
# | B             | Sim, um             |
# | C             | Sim, dois           |
# | D             | Sim, três           |
# | E             | Sim, quatro ou mais |
#
# </br>
#
# ## Q025
# ---
# Informação sobre acesso a internet na residência do inscrito
#
# |**Categoria**  | **Descrição**   |
# |:-------------:|:---------------:|
# | A             | Não             |
# | B             | Sim             |

# %%
enem_df = pd.read_csv('/content/MICRODADOS_ENEM_2021.csv', sep=';', encoding='latin-1')
enem_df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
enem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34073 entries, 0 to 34072
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            34073 non-null  int64
#  1   NU_ANO                  34073 non-null  int64
#  2   TP_FAIXA_ETARIA         34073 non-null  int64
#  3   TP_SEXO                 34073 non-null  object
#  4   TP_ESTADO_CIVIL         34073 non-null  int64
#  5   TP_COR_RACA             34073 non-null  int64
#  6   TP_NACIONALIDADE        34073 non-null  int64
#  7   TP_ST_CONCLUSAO         34073 non-null  int64
#  8   TP_ANO_CONCLUIU         34073 non-null  int64
#  9   TP_ESCOLA               34073 non-null  int64
#  10  TP_ENSINO               14090 non-null  float64
#  11  IN_TREINEIRO            34073 non-null  int64
#  12  CO_MUNICIPIO_ESC        8245 non-null   float64
#  13  NO_MUNICIPIO_ESC        8245 non-null   object
# ...

# %%
var = ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q006', 'Q022', 'Q024', 'Q025']

# %%
enem_df[var].head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025
# 0    B    B
# 1    A    A
# 2    B    B
# ...

# %%
enem_df = enem_df[var]
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025
# 0    B    B
# 1    A    A
# 2    B    B
# ...

# %% [markdown]
# ## Distribuição de frequência
# ---
# Uma distribuição de frequência é um método de agrupamento de dados em classes, ou intervalos, de tal forma que se possa determinar o número, ou a porcentagem (isto é, a frequência) de cada classe, podendo ser apresentada sob a forma gráfica ou tabular.
#
# O primeiro passo em um trabalho de análise é o conhecimento do comportamento das variáveis envolvidas no estudo.

# %%
# 1 - Precisamos estabelecer as classes ou intervalos de agrupamentos dos dados;
# 2 - Enquadrar os dados nas, mediamente contagem;
# 3 - Contar o número em cada classe;
# 4 - Por fim, apresentar os resultados em uma tabela ou gráfico.

# %% [markdown]
# ### Método 1

# %%
enem_df['TP_SEXO']
# Out:
# 0        F
# 1        M
# 2        F
# 3        M
# 4        F
#         ..
# 34068    F
# 34069    F
# 34070    F
# 34071    F
# 34072    F
# Name: TP_SEXO, Length: 34073, dtype: object

# %%
enem_df['TP_SEXO'].value_counts()
# Out:
# F    23933
# M    10140
# Name: TP_SEXO, dtype: int64

# %%
enem_df['TP_SEXO'].value_counts(normalize=True)
# Out:
# F    0.702404
# M    0.297596
# Name: TP_SEXO, dtype: float64

# %%
enem_df['TP_SEXO'].value_counts(normalize=True) * 100
# Out:
# F    70.240366
# M    29.759634
# Name: TP_SEXO, dtype: float64

# %%
frequencia = enem_df['TP_SEXO'].value_counts()
porcentagem = enem_df['TP_SEXO'].value_counts(normalize=True) * 100

# %%
distribuicao_frequencia_sexo = pd.DataFrame(
    {
        'Frrequencia': frequencia,
        'porcentagem': porcentagem
    }
)

distribuicao_frequencia_sexo
# Out:
#    Frrequencia  porcentagem
# F        23933    70.240366
# M        10140    29.759634

# %%
distribuicao_frequencia_sexo.rename(index={'F': 'Feminino', 'M': 'Masculino'}, inplace=True)
distribuicao_frequencia_sexo.rename_axis('Sexo', axis='columns', inplace=True)

# %%
distribuicao_frequencia_sexo
# Out:
# Sexo       Frrequencia  porcentagem
# Feminino         23933    70.240366
# Masculino        10140    29.759634

# %% [markdown]
# ### Método 2

# %% [markdown]
# [https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html]()

# %%
sexo = {'M': 'Masculino', 'F': 'Feminino'}
internet = {'A': 'Não', 'B': 'Sim'}

# %%
frequencia_internet_sexo = pd.crosstab(
    enem_df['TP_SEXO'],
    enem_df['Q025']
)

frequencia_internet_sexo
# Out:
# Q025        A      B
# TP_SEXO
# F        2634  21298
# M        1094   9046

# %%
frequencia_internet_sexo.rename(index=sexo, inplace=True)
frequencia_internet_sexo.rename(columns=internet, inplace=True)
frequencia_internet_sexo.rename_axis('Internet', axis='columns', inplace=True)
frequencia_internet_sexo.rename_axis('Sexo', axis='rows', inplace=True)

frequencia_internet_sexo
# Out:
# Internet    Não    Sim
# Sexo
# Feminino   2634  21298
# Masculino  1094   9046

# %% [markdown]
# ## Distribuição de frequências para variáveis quantitativas (classes personalizadas)

# %% [markdown]
# ### Passo 1 - Especificar os limites de cada classe
#
# Utilizar a sequinte classificação para a RENDA FAMILIAR:
# <p> <br />
#
# **A >** Acima de 20 SM
#
# **B >** De 10 a 20 SM
#
# **C >** De 4 a 10 SM
#
# **D >** De 2 a 4 SM
#
# **E >** Até 2 SM
#
# Onde **SM** é o valor do salário mínimo na época. Em nosso caso **R$ 1.1000,00** (2021):
#
# **A >** Acima de 22.000
#
# **B >** De 11.000 a 22.000
#
# **C >** De 4.400 a 11.000
#
# **D >** De 2.200 a 4.400
#
# **E >** Até 1.100

# %%
def mapear_renda_familiar(categoria_renda):
  if categoria_renda in ['A', 'B']:
    return 1_100
  elif categoria_renda in ['C', 'D', 'E', 'F', 'G']:
    return 4_400
  elif categoria_renda in ['H', 'I', 'J', 'K', 'L', 'M']:
    return 11_000
  elif categoria_renda in ['N', 'O', 'P']:
    return 22_000
  else:
    return 23_000

# %%
enem_df['Q006']
# Out:
# 0          D
# 1          B
# 2          C
# 3          B
# 4          C
#         ...
# 34068      D
# 34069      B
# 34070      A
# 34071      B
# 34072    NaN
# Name: Q006, Length: 34073, dtype: object

# %%
enem_df['Q006'].apply(mapear_renda_familiar)
# Out:
# 0         4400
# 1         1100
# 2         4400
# 3         1100
# 4         4400
#          ...
# 34068     4400
# 34069     1100
# 34070     1100
# 34071     1100
# 34072    23000
# Name: Q006, Length: 34073, dtype: int64

# %%
enem_df['renda_familiar'] = enem_df['Q006'].apply(mapear_renda_familiar)
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# ...

# %%
classes = [0, 2_200, 4_400, 11_000, 22_000, 23_000]

# %%
labels = ['E', 'D', 'C', 'B', 'A']

# %% [markdown]
# ### Passo - 2 Criar a tabela de frequências

# %% [markdown]
# [https://pandas.pydata.org/docs/reference/api/pandas.cut.html]()

# %%
pd.cut(
    x = enem_df['renda_familiar'],
    bins = classes,
    labels = labels,
    include_lowest=True
)
# Out:
# 0        D
# 1        E
# 2        D
# 3        E
# 4        D
#         ..
# 34068    D
# 34069    E
# 34070    E
# 34071    E
# 34072    A
# Name: renda_familiar, Length: 34073, dtype: category
# Categories (5, object): ['E' < 'D' < 'C' < 'B' < 'A']

# %%
pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    )
)
# Out:
# D    15861
# E    14504
# C     2770
# B      638
# A      300
# Name: renda_familiar, dtype: int64

# %%
frequencia_renda_familiar = pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    )
)

frequencia_renda_familiar
# Out:
# D    15861
# E    14504
# C     2770
# B      638
# A      300
# Name: renda_familiar, dtype: int64

# %%
porcentagem_renda_familiar = pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    ),
    normalize=True
) * 100

porcentagem_renda_familiar
# Out:
# D    46.550054
# E    42.567429
# C     8.129604
# B     1.872450
# A     0.880463
# Name: renda_familiar, dtype: float64

# %%
porcentagem_renda_familiar = round(pd.value_counts(
    pd.cut(
        x = enem_df['renda_familiar'],
        bins = classes,
        labels = labels,
        include_lowest=True
    ),
    normalize=True
) * 100, 2)

porcentagem_renda_familiar
# Out:
# D    46.55
# E    42.57
# C     8.13
# B     1.87
# A     0.88
# Name: renda_familiar, dtype: float64

# %%
distribuicao_frequencia_renda_familiar = pd.DataFrame(
    {
        'Frequencia': frequencia_renda_familiar,
        'Porcentagem (%)': porcentagem_renda_familiar
    }
)

distribuicao_frequencia_renda_familiar
# Out:
#    Frequencia  Porcentagem (%)
# D       15861            46.55
# E       14504            42.57
# C        2770             8.13
# B         638             1.87
# A         300             0.88

# %%
distribuicao_frequencia_renda_familiar.sort_index()
# Out:
#    Frequencia  Porcentagem (%)
# E       14504            42.57
# D       15861            46.55
# C        2770             8.13
# B         638             1.87
# A         300             0.88

# %%
distribuicao_frequencia_renda_familiar.sort_index(ascending=False)
# Out:
#    Frequencia  Porcentagem (%)
# A         300             0.88
# B         638             1.87
# C        2770             8.13
# D       15861            46.55
# E       14504            42.57

# %% [markdown]
# ## Distribuição de frequências para variáveis quantitativas (Classes de amplitude fixa)

# %% [markdown]
# ### Passo 1 - Definindo o número de calsses

# %% [markdown]
# #### Regra de Sturges
#
#
# $k = 1 + \frac{10}{3} \log_{10}(n)$

# %%
enem_df.shape
# Out:
# (34073, 15)

# %%
n = enem_df.shape[0]
n
# Out:
# 34073

# %%
k = 1 + (10 / 3) * np.log10(n)
k
# Out:
# 16.10803457751146

# %%
int(k)
# Out:
# 16

# %%
round(k)
# Out:
# 16

# %%
k = round(k)
k
# Out:
# 16

# %% [markdown]
# ### Passo - 2 Craiar a tabela de frequências

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 34068    513.2
# 34069      NaN
# 34070      NaN
# 34071    446.8
# 34072      NaN
# Name: NU_NOTA_MT, Length: 34073, dtype: float64

# %%
frequencia_nota_matematica = pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
      bins = k,
      include_lowest=True
)
    )

frequencia_nota_matematica
# Out:
# (416.981, 476.55]     6484
# (476.55, 536.119]     4991
# (536.119, 595.688]    3831
# (357.412, 416.981]    3748
# (595.688, 655.256]    3159
# (655.256, 714.825]    2195
# (714.825, 774.394]    1336
# (774.394, 833.962]     557
# (833.962, 893.531]     169
# (893.531, 953.1]        34
# (297.844, 357.412]      24
# (-0.954, 59.569]         4
# (59.569, 119.138]        0
# (119.138, 178.706]       0
# (178.706, 238.275]       0
# (238.275, 297.844]       0
# Name: NU_NOTA_MT, dtype: int64

# %%
porcentagem_nota_matematica = pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
        bins = k,
        include_lowest=True
    ),
    normalize=True
)

porcentagem_nota_matematica
# Out:
# (416.981, 476.55]     0.244384
# (476.55, 536.119]     0.188112
# (536.119, 595.688]    0.144392
# (357.412, 416.981]    0.141263
# (595.688, 655.256]    0.119064
# (655.256, 714.825]    0.082730
# (714.825, 774.394]    0.050354
# (774.394, 833.962]    0.020994
# (833.962, 893.531]    0.006370
# (893.531, 953.1]      0.001281
# (297.844, 357.412]    0.000905
# (-0.954, 59.569]      0.000151
# (59.569, 119.138]     0.000000
# (119.138, 178.706]    0.000000
# (178.706, 238.275]    0.000000
# (238.275, 297.844]    0.000000
# Name: NU_NOTA_MT, dtype: float64

# %%
porcentagem_nota_matematica = round(pd.value_counts(
    pd.cut(
        x = enem_df['NU_NOTA_MT'],
        bins = k,
        include_lowest=True
    ),
    normalize=True
), 2)

porcentagem_nota_matematica
# Out:
# (416.981, 476.55]     0.24
# (476.55, 536.119]     0.19
# (536.119, 595.688]    0.14
# (357.412, 416.981]    0.14
# (595.688, 655.256]    0.12
# (655.256, 714.825]    0.08
# (714.825, 774.394]    0.05
# (774.394, 833.962]    0.02
# (833.962, 893.531]    0.01
# (893.531, 953.1]      0.00
# (297.844, 357.412]    0.00
# (-0.954, 59.569]      0.00
# (59.569, 119.138]     0.00
# (119.138, 178.706]    0.00
# (178.706, 238.275]    0.00
# (238.275, 297.844]    0.00
# Name: NU_NOTA_MT, dtype: float64

# %%
distribuicao_frequencia_nota_matematica = pd.DataFrame(
    {
        'Frequencia': frequencia_nota_matematica,
        'Porcentagem (%)': porcentagem_nota_matematica
    }
)

distribuicao_frequencia_nota_matematica
# Out:
#                     Frequencia  Porcentagem (%)
# (416.981, 476.55]         6484             0.24
# (476.55, 536.119]         4991             0.19
# (536.119, 595.688]        3831             0.14
# (357.412, 416.981]        3748             0.14
# (595.688, 655.256]        3159             0.12
# (655.256, 714.825]        2195             0.08
# (714.825, 774.394]        1336             0.05
# (774.394, 833.962]         557             0.02
# (833.962, 893.531]         169             0.01
# (893.531, 953.1]            34             0.00
# (297.844, 357.412]          24             0.00
# (-0.954, 59.569]             4             0.00
# (59.569, 119.138]            0             0.00
# (119.138, 178.706]           0             0.00
# (178.706, 238.275]           0             0.00
# (238.275, 297.844]           0             0.00

# %% [markdown]
# ## Histograma
# ---
# O **HISTOGRAMA** é a representação gráfica de uma distribuição de frequências. É um gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à fequência da classe que ele representa.

# %%
distribuicao_frequencia_nota_matematica
# Out:
#                     Frequencia  Porcentagem (%)
# (416.981, 476.55]         6484             0.24
# (476.55, 536.119]         4991             0.19
# (536.119, 595.688]        3831             0.14
# (357.412, 416.981]        3748             0.14
# (595.688, 655.256]        3159             0.12
# (655.256, 714.825]        2195             0.08
# (714.825, 774.394]        1336             0.05
# (774.394, 833.962]         557             0.02
# (833.962, 893.531]         169             0.01
# (893.531, 953.1]            34             0.00
# (297.844, 357.412]          24             0.00
# (-0.954, 59.569]             4             0.00
# (59.569, 119.138]            0             0.00
# (119.138, 178.706]           0             0.00
# (178.706, 238.275]           0             0.00
# (238.275, 297.844]           0             0.00

# %%
distribuicao_frequencia_nota_matematica['Frequencia'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(distribuicao_frequencia_nota_matematica['Frequencia'])
# Out:
# <Axes: xlabel='Frequencia', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'])
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'], bins=100)
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %%
sns.histplot(enem_df['NU_NOTA_CH'], bins=100, kde=True)
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %% [markdown]
# ## **Medidas Estatísticas**
#
# * As **medidas de tendência** central mostram o valor representativo em torno do qual os dados tendem a agrupar-se,
#
# * As **medidas de dispersão** mostram o grau de afastamento dos valores observados em relação ao ponto central da
#
# * As **medidas de posição relativa** mostram pontos de corte na distribuição relativa dos dados da amostra.

# %% [markdown]
# ### Medidas de Tendência Central
#
# As medidas de tendência ou "de posição" procuram caracterizar a tendência do conjunto (valor "típico") a um valor numérico que "represente" o conjunto. Esse valor pode ser calculado levando em conta todos os valores do conjunto ou apenas alguns valores ordenados.

# %% [markdown]
# #### Média
#
# A média aritmética simples é a soma dos valores observados dividida pelo número desses valores, definida da seguinte forma:
#
# ![](https://arquivos.respondeai.com.br/seo/2023/aedc5b6d-bd3b-49b6-b780-53ad3f6087ff.webp)
#
#
# * Existem duas formas de se calcular a média.

# %%
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# ...

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 34068    513.2
# 34069      NaN
# 34070      NaN
# 34071    446.8
# 34072      NaN
# Name: NU_NOTA_MT, Length: 34073, dtype: float64

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / len(enem_df['NU_NOTA_MT'])
nota_matematica_01
# Out:
# 415.28993337833475

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / enem_df['NU_NOTA_MT'].shape[0]
nota_matematica_01
# Out:
# 415.28993337833475

# %%
enem_df['NU_NOTA_MT'].mean()
# Out:
# 533.3248115483191

# %%
enem_df['NU_NOTA_MT']
# Out:
# 0          NaN
# 1        461.5
# 2          NaN
# 3        659.5
# 4        582.6
#          ...
# 34068    513.2
# 34069      NaN
# 34070      NaN
# 34071    446.8
# 34072      NaN
# Name: NU_NOTA_MT, Length: 34073, dtype: float64

# %%
enem_df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                5       F            1       NaN                     NaN
# 1               12       M            1       NaN                     NaN
# 2               13       F            1       NaN                     NaN
# 3                3       M            3        CE                     2.0
# 4                2       F            3        CE                     2.0
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 0         NaN       574.6       472.6         NaN            760.0    D    B
# 1       505.9       551.8       498.3       461.5            560.0    B    C
# 2         NaN         NaN         NaN         NaN              NaN    C    C
# 3       580.7       678.9       638.9       659.5            780.0    B    B
# 4       497.7       532.4       457.6       582.6            780.0    C    E
#
#   Q024 Q025  renda_familiar
# 0    B    B            4400
# ...

# %%
print(f"Antes: {enem_df.shape}")
# Out:
# Antes: (34073, 15)

# %%
# Retirando os valores faltantes na base de dados

enem_df.dropna(inplace=True)

# %%
print(f"Agora: {enem_df.shape}")
# Out:
# Agora: (7073, 15)

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3       M            3        CE                     2.0
# 4                 2       F            3        CE                     2.0
# 33                3       M            1        BA                     2.0
# 45                4       F            3        ES                     1.0
# 51                3       M            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
nota_matematica_01 = enem_df['NU_NOTA_MT'].sum() / len(enem_df['NU_NOTA_MT'])
nota_matematica_01
# Out:
# 544.4583486497951

# %%
nota_matematica_02 = enem_df['NU_NOTA_MT'].mean()
nota_matematica_02
# Out:
# 544.4583486497951

# %% [markdown]
# #### Medianda
#
# A mediana é o valor médio ou a média aritmética de dois valores centrais de um conjunto de números ordenados (crescente ou decrescente)

# %%
enem_df['NU_NOTA_MT'].median()
# Out:
# 526.5

# %%
enem_df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_REDACAO']].mean()
# Out:
# NU_NOTA_CN         493.393949
# NU_NOTA_CH         531.745568
# NU_NOTA_LC         512.160681
# NU_NOTA_REDACAO    669.506574
# dtype: float64

# %% [markdown]
# #### *Média x Mediana*
#
# è sempre necessárioobservar ambas as medidas, cada medida depende diretamente de como estão distribuídos os dados. No exemplo a seguir iremos utilizar dois exemplos de conjuntos de dados.
#
# Conjunto1 = [1, 2, 3, 4, 5]
#
# Conjunto2 = [1, 2, 3, 4, 50]
#
# A seguir iremos aplicar o cálculo da média e da mediana para ambos os conjuntos.

# %%
# Conjunto de dados
conjunto1 = [1, 2, 3, 4, 5]
conjunto2 = [1, 2, 3, 4, 50]

# %%
pd.Series(conjunto1).median()
# Out:
# 3.0

# %%
pd.Series(conjunto2).median()
# Out:
# 3.0

# %%
pd.Series(conjunto1).mean()
# Out:
# 3.0

# %%
pd.Series(conjunto2).mean()
# Out:
# 12.0

# %% [markdown]
# As duas amostras se diferenciam apenas pelo **último valor**, foi inserido um valor discrepante, chamado de **outlier**. Um *outlier* é um valor que é muito diferente dos demais, quando presentes na amostra, esses valores acabam por "contaminar" a **MÉDIA**.
#
# O outlier distorce a média, devido a este problema, quando for escolher uma medida de tendência central, é importante analisar os dados, se a média e a mediana estiverem próximas é possível que não existam valores discrepantes na amostra.
#
# Se **não houverem valores discrepantes** na amostra a melhor escolha á a **média**, mas ainda assim é importante calcular a mediana e analisar os dois valores.
#
# Caso **existam valores discrepantes** o melhor usar é a **mediana**
#
# É importante entender os valores discrepantes. Nem sempre um valor discrepante é um erro nos dados. Caso seja um erro, esse valor deverá ser eliminado da amostra e refeito os cálculos da média e mediana, analisando novamente os dois valores. Se o valor não for um erro, deve-se analisar os valores de forma separada, pois esses valores podem ser exatamente o que se busca na amostra.
#
# A mediana deve ser usada, sempre que possível, como medida representativa de distribuições fortemente assimétricas, como por exemplo a variável distribuição de renda.

# %% [markdown]
# #### Moda
#
# A moda é o valor que ocorre com maior frequência em um dado conjunto de dados.

# %%
enem_df['NU_NOTA_CH'].mode()
# Out:
# 0    551.7
# Name: NU_NOTA_CH, dtype: float64

# %%
enem_df['TP_FAIXA_ETARIA'].mode()
# Out:
# 0    2
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
enem_df['TP_COR_RACA'].mode()
# Out:
# 0    3
# Name: TP_COR_RACA, dtype: int64

# %% [markdown]
# **Atenção:** A moda pode não existir

# %%
teste_moda_1 = [1, 2, 3, 4, 5]
pd.Series(teste_moda_1).mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
teste_moda_2 = [1, 1, 2, 3, 4, 4, 5]
pd.Series(teste_moda_2).mode()
# Out:
# 0    1
# 1    4
# dtype: int64

# %% [markdown]
# #### Outras médias
#
# Algumas vezes é interessante calcular médias de forma diferente para dados com características especiais.

# %% [markdown]
# #### Média Geométrica
#
# As médias geométricas são bastante empregadas para observações positivas referentes a crescimentos exponenciais, definida da seguinte forma:
#
# ![](https://blog.professorferretto.com.br/wp-content/uploads/2019/05/descricao-da-formula-da-media-geometrica.png)

# %% [markdown]
# #### Média Harmônica
#
# Para fenômenos que dependem fortemente do menor dos dados, em geral, utiliza-se médias hamônicas calculadas como o inverso da média dos inversos de um conjunto de dados, definida da seguinte forma:
#
# ![](https://s5.static.brasilescola.uol.com.br/be/2021/09/1-formula-media-harmonica.jpg)
#
# Para o cálculo das médias geometricas e harmônicas utilizaremos as funções `gmean()` e `hmean()`, respectivamente, do módulo *scipy.stats* da biblioteca SciPy. o módulo *scipy.stats* contém um grande número de distribuições de probabilidades, bem como uma crescente biblioteca de funções estatísticas.

# %%
from scipy import stats

# %%
teste_outras_medias = {
    'atributo_1': [2, 6, 15, 59],
    'atributo_2': [2000, 20, 250, 1500]
}

# %%
outras_medias_df = pd.DataFrame(teste_outras_medias)
outras_medias_df
# Out:
#    atributo_1  atributo_2
# 0           2        2000
# 1           6          20
# 2          15         250
# 3          59        1500

# %%
media_geometrica = stats.gmean(outras_medias_df['atributo_1'], axis=0)
print(f'Média Geometrica atributo_1: {media_geometrica}')
# Out:
# Média Geometrica atributo_1: 10.151521276336176

# %%
media_harmonica = stats.hmean(outras_medias_df['atributo_2'], axis=0)
print(f'Média Harmônica atributo_2: {media_harmonica}')
# Out:
# Média Harmônica atributo_2: 72.50755287009062

# %% [markdown]
# ### Relação entre média, mediana e moda

# %%
notas_mt = enem_df['NU_NOTA_MT']
notas_lc = enem_df['NU_NOTA_LC']

# %%
# Para as notas de matemática
media_notas_mt = notas_mt.mean()
mediana_notas_mt = notas_mt.median()
moda_notas_mt = notas_mt.mode()

# %%
print(f'Média MT: {media_notas_mt}')
print(f'Mediana MT: {mediana_notas_mt}')
print(f'Moda MT: {moda_notas_mt}')
# Out:
# Média MT: 544.4583486497951
# Mediana MT: 526.5
# Moda MT: 0    432.7
# 1    446.9
# 2    492.9
# Name: NU_NOTA_MT, dtype: float64

# %%
notas_mt.hist(bins=100);

# %%
# Para as notas LC
media_notas_lc = notas_lc.mean()
mediana_notas_lc = notas_lc.median()
moda_notas_lc = notas_lc.mode()

# %%
print(f'Média LC: {media_notas_lc}')
print(f'Mediana LC: {mediana_notas_lc}')
print(f'Moda LC: {moda_notas_lc}')
# Out:
# Média LC: 512.160681464725
# Mediana LC: 515.2
# Moda LC: 0    517.8
# Name: NU_NOTA_LC, dtype: float64

# %%
notas_lc.hist(bins=100);

# %%
pnad_df = pd.read_csv('')
pnad_df.head()

# %%
altura = pnad_df['Altura']

# %%
media_altura = altura.mean()
mediana_altura = altura.median()
moda_altura = altura.mode()

# %%
print(f'Média altura: {media_altura}')
print(f'Mediana altura: {mediana_altura}')
print(f'Moda altura: {moda_altura}')

# %%
altura.hist(bins=100);

# %% [markdown]
# ### Medidas de posição

# %% [markdown]
# #### Quartis, decis e percentis
#
# Há uma série de medidas de posição semelhantes na sua concepção à mediana, embora não sejam medidas de tendência central. Como se sabe, a mediana divide a distribuição em duas partes iguais quanto ao número de elementos de cada parte. Já os quartis permitem dividir a distribuição em quatro partes iguais quanto ao número de elementos de cada uma; os decis em dez partes e os centis em cem partes iguais.
#
#
# **Quartis**
#
# São os elementos da distribuição da variável que dividem as observações em quatro partes iguais, considerando que a variável esteja com seus valores organizados de forma crescente.
#
#
# *   1° Quartil: 25% das observações são menores do que o 1° quartil
# *   2° Quartil: trata-se da mediana
# *   3° Quartil: 25% das observações são maiores do que o 3° quartil
# *   1° Quartil = 25° Percentil
# *   2° Quartil = 50° Percentil
# *   3° Quartil = 75° Percentil

# %% [markdown]
# #### Decis
#
# São os elementos da distribuição da variável que dividem as observações em dez partes iguais, considerando que a variável esteja com seus valores organizados de forma crescente.
#
#
# *   1° Decil
# *   3° Decil
# *   8° Decil...
# *   1° Decil = 10° Percentil
# *   3° Decil = 30° Percentil
# *   8° Decil = 80° Percentil

# %%
# Quartis

quartis = [0.25, 0.50, 0.75]

# %%
notas_mt = enem_df['NU_NOTA_MT']
print('Quartis da Nota de MT')
notas_mt.quantile(q=quartis)
# Out:
# Quartis da Nota de MT
# 0.25    451.7
# 0.50    526.5
# 0.75    626.3
# Name: NU_NOTA_MT, dtype: float64

# %%
decil = [i / 10 for i in range(1, 10)]

# %%
print('Decil da Nota de MT')
notas_mt.quantile(q=decil)
# Out:
# Decil da Nota de MT
# 0.1    411.32
# 0.2    438.50
# 0.3    464.80
# 0.4    493.08
# 0.5    526.50
# 0.6    562.90
# 0.7    604.70
# 0.8    647.12
# 0.9    704.60
# Name: NU_NOTA_MT, dtype: float64

# %%
quantil = [i / 100 for i in range(1, 100)]

# %%
print('Quantil da Nota de MT')
notas_mt.quantile(q=quantil)
# Out:
# Quantil da Nota de MT
# 0.01    372.700
# 0.02    380.544
# 0.03    385.700
# 0.04    390.800
# 0.05    394.700
#          ...
# 0.95    747.920
# 0.96    759.912
# 0.97    776.784
# 0.98    794.956
# 0.99    828.452
# Name: NU_NOTA_MT, Length: 99, dtype: float64

# %% [markdown]
# ### Medidas de Dispersão ou Variabilidade
#
# As medidas de dispersão ou variabilidade indicam se os valores de conjunto de dados estão relativamente próximos uns dos outros, ou seprados. Todas elas têm na média o ponto de referência.

# %% [markdown]
# #### Amplitude
#
# A amplitude ou intervalo total (**It**) de um conjunto de dados (x1, x2,...,xn) é a diferença entre o maior valor e o menor valor, definido da seguinte forma:
#
# it = Xmax - Xmin
#
# onde
#
# Xmax = valor máximo do conjunto de dados, isto é, max{x1,x2,...xn}
#
# Xmin = valor mínimo do conjunto de dados, isto é, min{x1,x2,...xn}

# %%
notas_mt = enem_df[['NU_NOTA_MT']].copy()
notas_mt.head()
# Out:
#     NU_NOTA_MT
# 3        659.5
# 4        582.6
# 33       423.0
# 45       570.2
# 51       579.4

# %%
nota_max_mt = notas_mt.max()
nota_max_mt
# Out:
# NU_NOTA_MT    948.8
# dtype: float64

# %%
nota_min_mt = notas_mt.min()
nota_min_mt
# Out:
# NU_NOTA_MT    0.0
# dtype: float64

# %%
amplitude_nota_mt = nota_max_mt - nota_min_mt
amplitude_nota_mt
# Out:
# NU_NOTA_MT    948.8
# dtype: float64

# %% [markdown]
# #### Desvio médio absoluto

# %%
media_nota_mt = notas_mt['NU_NOTA_MT'].mean()
media_nota_mt
# Out:
# 544.4583486497951

# %%
notas_mt['Desvio'] = notas_mt['NU_NOTA_MT'] - media_nota_mt
notas_mt.head()
# Out:
#     NU_NOTA_MT      Desvio
# 3        659.5  115.041651
# 4        582.6   38.141651
# 33       423.0 -121.458349
# 45       570.2   25.741651
# 51       579.4   34.941651

# %%
notas_mt['|Desvio|'] = notas_mt['Desvio'].abs()
notas_mt.head()
# Out:
#     NU_NOTA_MT      Desvio    |Desvio|
# 3        659.5  115.041651  115.041651
# 4        582.6   38.141651   38.141651
# 33       423.0 -121.458349  121.458349
# 45       570.2   25.741651   25.741651
# 51       579.4   34.941651   34.941651

# %%
notas_mt['|Desvio|'].sum() / len(notas_mt)
# Out:
# 94.05119738453357

# %% [markdown]
# #### Variância
#
#
# A variância é construída a partir das diferenças entre cada observação e a média dos dados, ou seja, o desvio em torno da média. No cálculo da variância, os desvios em torno da média são elevados ao quadro.
#
#
# Variância populacional
#
# ![](https://knoow.net/wp-content/uploads/2018/12/variancia-400x170.jpg)

# %% [markdown]
# #### Variância amostral
#
#
# ![](https://knoow.net/wp-content/uploads/2018/12/variancia2-400x139.jpg)

# %%
notas_mt.head()
# Out:
#     NU_NOTA_MT      Desvio    |Desvio|
# 3        659.5  115.041651  115.041651
# 4        582.6   38.141651   38.141651
# 33       423.0 -121.458349  121.458349
# 45       570.2   25.741651   25.741651
# 51       579.4   34.941651   34.941651

# %%
notas_mt['(Desvio)^2'] = notas_mt['Desvio'].pow(2)
notas_mt.head()
# Out:
#     NU_NOTA_MT      Desvio    |Desvio|    (Desvio)^2
# 3        659.5  115.041651  115.041651  13234.581545
# 4        582.6   38.141651   38.141651   1454.785568
# 33       423.0 -121.458349  121.458349  14752.130457
# 45       570.2   25.741651   25.741651    662.632614
# 51       579.4   34.941651   34.941651   1220.918999

# %%
notas_mt['(Desvio)^2'].sum() / (len(notas_mt) - 1)
# Out:
# 12698.803892747768

# %%
variancia_notas_mt = notas_mt['NU_NOTA_MT'].var()
variancia_notas_mt
# Out:
# 12698.803892747768

# %% [markdown]
# ### Desvio Padrão
#
#
# Uma das restrições da variância é o fato de fornecer medidas em quadrados das unidades originais - a variância de medidas de comprimento, por exemplo, é em unidades de área. logo, o fato de as unidades serem diferentes dificulta a comparação da dispersão com as variáveis que a definem. um modo de eliminar essa dificuldade é considerar sua raiz quadrada.

# %% [markdown]
# #### Desvio padrão populacional

# %% [markdown]
# #### Desvio padrão amostral

# %%
np.sqrt(variancia_notas_mt)
# Out:
# 112.688969703107

# %%
desvio_padrao_notas_mt = notas_mt['NU_NOTA_MT'].std()
desvio_padrao_notas_mt
# Out:
# 112.688969703107

# %% [markdown]
# **Atenção:** O *pandas* disponibiliza a função *describe()* que gera as estatísticas descritivas que resumem a tendência central, a dispersão e a forma da distribuição de um conjunto de dados, excluindo os valores de NaN. Analisa séries numéricas e de objetos, bem como conjuntos de colunas DataFrame de tipos de dados mistos.

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3       M            3        CE                     2.0
# 4                 2       F            3        CE                     2.0
# 33                3       M            1        BA                     2.0
# 45                4       F            3        ES                     1.0
# 51                3       M            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
notas_df = enem_df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']]
notas_df
# Out:
#        NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 3           580.7       678.9       638.9       659.5            780.0
# 4           497.7       532.4       457.6       582.6            780.0
# 33          414.6       410.1       386.7       423.0            700.0
# 45          476.8       608.5       534.2       570.2            640.0
# 51          433.4       622.0       548.3       579.4            680.0
# ...           ...         ...         ...         ...              ...
# 34062       551.8       521.8       513.4       649.3            580.0
# 34065       607.2       631.8       626.1       705.3            700.0
# 34067       420.8       389.2       353.6       405.3            540.0
# 34068       416.5       496.4       439.4       513.2            620.0
# 34071       440.4       409.9       421.3       446.8              0.0
#
# [7073 rows x 5 columns]

# %%
notas_df.describe()
# Out:
#         NU_NOTA_CN   NU_NOTA_CH   NU_NOTA_LC   NU_NOTA_MT  NU_NOTA_REDACAO
# count  7073.000000  7073.000000  7073.000000  7073.000000      7073.000000
# mean    493.393949   531.745568   512.160681   544.458349       669.506574
# std      81.334527    93.345391    76.070188   112.688970       187.196201
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%     432.000000   460.000000   459.500000   451.700000       560.000000
# 50%     482.400000   535.300000   515.200000   526.500000       680.000000
# 75%     548.800000   599.000000   566.000000   626.300000       820.000000
# max     816.400000   814.300000   788.600000   948.800000      1000.000000

# %% [markdown]
# ## Visualização gráfica de dados

# %% [markdown]
# A apresentação dos dados estatísticos através de tabelas ou medidas de centralidade e variabilidade e variabilidade nem sempre proporciona um entendimento adequado dos dados. Assim, com a finalidade de melhorar esse processo, muitos recorrem ao uso dos gráficos.
#
# Regras gerais para construção de gráficos:
#
#   *   Os gráficos devem ser construídos de tal maneira que a frase "basta olhar para entender" seja válida;
#
#   *   Um gráfico deve conter um título e os seus eixos (X e Y) devem estar rotulados incluindo as unidades (gr, R$, Kg, etc.);
#
#   *   Um gráfico deve ser completo de tal maneira que todas as informações necessárias para entendê-lo devem estar sobre ele, o que o torna autoexplicativo;
#
#   *   Gráficos utilizados para comparação entre si devem ter a mesma escala, caso contrário a comparação fica comprometida;
#
#   *   Quando for construir gráficos de barras o valor zero deve ser o ponto de início dos eixos, caso isto não seja feito, ocorre uma distorção no gráfico.

# %% [markdown]
# ### Histograma
#
# O histograma representa a distribuição dos dados, formando compartimentos ao longo do intervalo dos dados, desenhados por barras para mostrar a frequência de observações dos dados em cada compartimento.
#
# Em resumo, o histograma mostra a distribuição das frequências de um conjunto de dados quantitativos contínuos ou discretos.
#
# O [histogrma](https://www.significados.com.br/histograma/) permite obter as seguintes informações:
#
#   - **Centralida**: qual é o centro de distribuição? Onde é esperado que esteja a maioria das observações?
#   - **Amplitude**: a distribuição normalmente contém observações entre quais valores? Qual é o ponto de máximo e o ponto de mínimo?
#   - **Simetria**: será que devemos esperar a mesma frequência de pontos com valor alto e com valor baixo? Será que o processo é simétrico ou valores mais altos são mais raros?

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3       M            3        CE                     2.0
# 4                 2       F            3        CE                     2.0
# 33                3       M            1        BA                     2.0
# 45                4       F            3        ES                     1.0
# 51                3       M            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
enem_df['NU_NOTA_MT'].hist(bins=100)
# Out:
# <Axes: >

# %%
sns.histplot(
    enem_df['NU_NOTA_CH'],
    bins=100
)
# Out:
# <Axes: xlabel='NU_NOTA_CH', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.despine(f)

sns.histplot(
    enem_df['NU_NOTA_MT'],
    bins=100
)
# Out:
# <Axes: xlabel='NU_NOTA_MT', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.histplot(
    enem_df['NU_NOTA_MT'],
    bins=100
)

plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.histplot(
    enem_df['NU_NOTA_MT'],
    bins=100
)

plt.title(
    'Distribuicao das Notas de Matematica do Enem de 2021',
    fontsize=18,
    fontweight='bold'
)

plt.xlabel(
    'Notas',
    fontsize=14
)

plt.ylabel(
    'Frequencia',
    fontsize=14
)

plt.show()

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3       M            3        CE                     2.0
# 4                 2       F            3        CE                     2.0
# 33                3       M            1        BA                     2.0
# 45                4       F            3        ES                     1.0
# 51                3       M            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
enem_df['TP_SEXO'] = enem_df['TP_SEXO'].map({'M': 'Masculino', 'F': 'Feminino'})
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino            3        CE                     2.0
# 4                 2   Feminino            3        CE                     2.0
# 33                3  Masculino            1        BA                     2.0
# 45                4   Feminino            3        ES                     1.0
# 51                3  Masculino            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
# ...

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.histplot(
    enem_df.query("TP_SEXO == 'Masculino'")['TP_FAIXA_ETARIA'],
    bins=20,
    label='Masculino',
    element='step',
    color='#da8b40'
)

plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.histplot(
    enem_df.query("TP_SEXO == 'Feminino'")['TP_FAIXA_ETARIA'],
    bins=20,
    label='Feminino',
    element='step',
    color='#257ca0'
)

sns.histplot(
    enem_df.query("TP_SEXO == 'Masculino'")['TP_FAIXA_ETARIA'],
    bins=20,
    label='Masculino',
    element='step',
    color='#da8b40'
)

plt.title(
    'Histograma de Candidatos por Sexo e Faixa Etaria',
    pad=20,
    fontsize=18,
    fontweight='bold'
)

plt.xlabel(
    'Faixa Etaria',
    fontsize=4
)

plt.ylabel(
    'Frequencia',
    fontsize=14
)

plt.legend()

plt.show()

# %% [markdown]
# ### Gráfico de barras ou colunas
#
# Utiliza o plano cartesiano com os valores ou categorias da variável no eixo X e as frequências ou porcentagens no eixo Y. Para cada valor da variável desenha-se uma barra com altura correspondendo à sua frequência ou porcentagem. Esse tipo de gráfico se adapta bem à variáveis qualitativas (ou categóricas).
#
# Exemplo de gráficos de barras que representam vendas de carros no primeiro trimestres de 2020. Dois exemplos com os mesmos dados, o primeiro exibe as barras verticalmente, já o segundo horizontalmente.

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino            3        CE                     2.0
# 4                 2   Feminino            3        CE                     2.0
# 33                3  Masculino            1        BA                     2.0
# 45                4   Feminino            3        ES                     1.0
# 51                3  Masculino            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
# ...

# %%
enem_df['TP_SEXO'].value_counts()
# Out:
# Feminino     4740
# Masculino    2333
# Name: TP_SEXO, dtype: int64

# %%
enem_df['TP_SEXO'].value_counts().plot

# %%
enem_df['TP_SEXO'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
sns.countplot(
    data=enem_df,
    x='TP_SEXO'
)
# Out:
# <Axes: xlabel='TP_SEXO', ylabel='count'>

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.countplot(
    data=enem_df,
    x='TP_SEXO'
)

plt.title(
    'Candidatos Inscritos por Sexo'
)

plt.xlabel(
    'Sexo'
)

plt.ylabel(
    'Inscritos'
)

plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.despine(f)

sns.countplot(
    data=enem_df,
    x='SG_UF_ESC'
)

plt.title(
    'Candidatos Inscritos por Estado'
)

plt.xlabel(
    'Estado'
)

plt.ylabel(
    'Inscritos'
)

plt.show()

# %% [markdown]
# ### Gráfico de linhas
#
# Sua construção é muito semelhante à do gráfico de barras porém utiliza-se linhas interligadas ao invés de barras para representar a frequência ou a porcentagem de cada valor ou categoria da variável estudada.
#
# É particularmente indicado para retratar séries temporais, ou seja, dados relativos a variáveis observadas anualmente, mensalmente, trimestralmente, de hora em hora, diariamente, etc.
#
# No exemplo a seguir o gráfico de linha mostra a evolução e comparação dos valores do dólar, por meses, nos anos de 2021 e 2022 no Brasil, disponibilizado pelo site: [https://br.investing.com/currencies/usd-brl](https://br.investing.com/currencies/usd-brl)

# %%
dolar_df = pd.read_csv('/content/USD_BRL Dados Históricos.csv')
dolar_df.head()
# Out:
#          Data  Último Abertura  Máxima  Mínima  Vol.    Var%
# 0  01.12.2022  5,2860   5,1856  5,3730  5,1160   NaN   1,95%
# 1  01.11.2022  5,1851   5,1803  5,5307  5,0184   NaN   0,12%
# 2  01.10.2022  5,1791   5,4158  5,4158  5,1083   NaN  -4,36%
# 3  01.09.2022  5,4154   5,1833  5,4300  5,0766   NaN   4,48%
# 4  01.08.2022  5,1831   5,1759  5,3163  5,0076   NaN   0,19%

# %%
dolar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      24 non-null     object
#  1   Último    24 non-null     object
#  2   Abertura  24 non-null     object
#  3   Máxima    24 non-null     object
#  4   Mínima    24 non-null     object
#  5   Vol.      0 non-null      float64
#  6   Var%      24 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ KB

# %%
from datetime import datetime


custom_date_parser = lambda data: datetime.strptime(data, '%d.%m.%y')

try:
    dolar_df = pd.read_csv(
        '/content/USD_BRL Dados Históricos.csv',
        parse_dates=['Data'],
        date_parser=custom_date_parser
    )
except ValueError as e:
    print(f"Erro: {e}")
    print("Verifique as datas no arquivo CSV para garantir que estão no formato correto.")

dolar_df.head()
# Out:
# Erro: unconverted data remains: 22
# Verifique as datas no arquivo CSV para garantir que estão no formato correto.
# <ipython-input-195-b50eb6ab0246>:7: FutureWarning:
#         Use pd.to_datetime instead.
#
#   dolar_df = pd.read_csv(
#          Data  Último Abertura  Máxima  Mínima  Vol.    Var%
# 0  01.12.2022  5,2860   5,1856  5,3730  5,1160   NaN   1,95%
# 1  01.11.2022  5,1851   5,1803  5,5307  5,0184   NaN   0,12%
# 2  01.10.2022  5,1791   5,4158  5,4158  5,1083   NaN  -4,36%
# 3  01.09.2022  5,4154   5,1833  5,4300  5,0766   NaN   4,48%
# 4  01.08.2022  5,1831   5,1759  5,3163  5,0076   NaN   0,19%

# %%
dolar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      24 non-null     object
#  1   Último    24 non-null     object
#  2   Abertura  24 non-null     object
#  3   Máxima    24 non-null     object
#  4   Mínima    24 non-null     object
#  5   Vol.      0 non-null      float64
#  6   Var%      24 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ KB

# %%
dolar_df['Último'].apply(lambda valor: float(valor.replace(',', '.')))
# Out:
# 0     5.2860
# 1     5.1851
# 2     5.1791
# 3     5.4154
# 4     5.1831
# 5     5.1734
# 6     5.2562
# 7     4.7315
# 8     4.9721
# 9     4.7390
# 10    5.1599
# 11    5.3041
# 12    5.5703
# 13    5.6239
# 14    5.6372
# 15    5.4428
# 16    5.1492
# 17    5.2123
# 18    4.9686
# 19    5.2172
# 20    5.4366
# 21    5.6315
# 22    5.5986
# 23    5.4625
# Name: Último, dtype: float64

# %%
dolar_df['Último'] = dolar_df['Último'].apply(lambda valor: float(valor.replace(',', '.')))
dolar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      24 non-null     object
#  1   Último    24 non-null     float64
#  2   Abertura  24 non-null     object
#  3   Máxima    24 non-null     object
#  4   Mínima    24 non-null     object
#  5   Vol.      0 non-null      float64
#  6   Var%      24 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.4+ KB

# %%
dolar_df['Data'].iloc[0]
# Out:
# '01.12.2022'

# %%
dolar_df['Data'] = dolar_df['Data'].apply(lambda data: data.replace('.', '-'))
dolar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      24 non-null     object
#  1   Último    24 non-null     float64
#  2   Abertura  24 non-null     object
#  3   Máxima    24 non-null     object
#  4   Mínima    24 non-null     object
#  5   Vol.      0 non-null      float64
#  6   Var%      24 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.4+ KB

# %%
dolar_df['Data'].iloc[0]
# Out:
# '01-12-2022'

# %%
dolar_df['Data'] = pd.to_datetime(dolar_df['Data'], format='%d-%m-%Y')
dolar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      24 non-null     datetime64[ns]
#  1   Último    24 non-null     float64
#  2   Abertura  24 non-null     object
#  3   Máxima    24 non-null     object
#  4   Mínima    24 non-null     object
#  5   Vol.      0 non-null      float64
#  6   Var%      24 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 1.4+ KB

# %%
dir(dolar_df['Data'].iloc[0])
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_as_unit',
#  '_date_repr',
#  '_freq',
#  '_freqstr',
#  '_from_dt64',
#  '_from_value_and_reso',
#  '_repr_base',
#  '_reso',
#  '_round',
#  '_set_freq',
#  '_short_repr',
#  '_time_repr',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
# ...

# %%
dolar_df['Data'].iloc[0].month_name()
# Out:
# 'December'

# %%
dolar_df['Mês'] = dolar_df['Data'].apply(lambda data: data.month_name())
dolar_df.head()
# Out:
#         Data  Último Abertura  Máxima  Mínima  Vol.    Var%        Mês
# 0 2022-12-01  5.2860   5,1856  5,3730  5,1160   NaN   1,95%   December
# 1 2022-11-01  5.1851   5,1803  5,5307  5,0184   NaN   0,12%   November
# 2 2022-10-01  5.1791   5,4158  5,4158  5,1083   NaN  -4,36%    October
# 3 2022-09-01  5.4154   5,1833  5,4300  5,0766   NaN   4,48%  September
# 4 2022-08-01  5.1831   5,1759  5,3163  5,0076   NaN   0,19%     August

# %%
meses = dolar_df.sort_values('Data')['Mês'].unique()
meses
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
dolar_df['Data'] = pd.to_datetime(dolar_df['Data'])
cotacao_2021 = dolar_df[dolar_df['Data'].dt.year == 2021]
cotacao_2021
# Out:
#          Data  Último Abertura  Máxima  Mínima  Vol.    Var%        Mês
# 12 2021-12-01  5.5703   5,6243  5,7579  5,5175   NaN  -0,95%   December
# 13 2021-11-01  5.6239   5,6221  5,7000  5,3879   NaN  -0,24%   November
# 14 2021-10-01  5.6372   5,4432  5,7547  5,3527   NaN   3,57%    October
# 15 2021-09-01  5.4428   5,1694  5,4767  5,1310   NaN   5,70%  September
# 16 2021-08-01  5.1492   5,2158  5,4757  5,1101   NaN  -1,21%     August
# 17 2021-07-01  5.2123   4,9705  5,3145  4,9467   NaN   4,90%       July
# 18 2021-06-01  4.9686   5,2210  5,2212  4,8929   NaN  -4,77%       June
# 19 2021-05-01  5.2172   5,4360  5,4843  5,1964   NaN  -4,04%        May
# 20 2021-04-01  5.4366   5,6330  5,7562  5,3274   NaN  -3,46%      April
# 21 2021-03-01  5.6315   5,5870  5,8787  5,4482   NaN   0,59%      March
# 22 2021-02-01  5.5986   5,4663  5,6093  5,3042   NaN   2,49%   February
# 23 2021-01-01  5.4625   5,1351  5,5166  5,1197   NaN   5,18%    January

# %%
dolar_df['Data'] = pd.to_datetime(dolar_df['Data'])
cotacao_2021 = dolar_df[dolar_df['Data'].dt.year == 2021].sort_values('Data')['Último'].values
cotacao_2021
# Out:
# array([5.4625, 5.5986, 5.6315, 5.4366, 5.2172, 4.9686, 5.2123, 5.1492,
#        5.4428, 5.6372, 5.6239, 5.5703])

# %%
cotacao_2022 = dolar_df[dolar_df['Data'].dt.year == 2022].sort_values('Data')['Último'].values
cotacao_2022
# Out:
# array([5.3041, 5.1599, 4.739 , 4.9721, 4.7315, 5.2562, 5.1734, 5.1831,
#        5.4154, 5.1791, 5.1851, 5.286 ])

# %%
len_m = min(len(meses), len(cotacao_2021), len(cotacao_2022))
meses = meses[:len_m]
cotacao_2021 = cotacao_2021[:len_m]
cotacao_2022 = cotacao_2022[:len_m]

f, ax = plt.subplots(figsize=(15, 8))

plt.plot(meses, cotacao_2021, label='2021', marker='o', color='red')
plt.plot(meses, cotacao_2022, label='2022', marker='o', color='blue')

plt.title(
    'Comparacao da variacao do dolar dos anos de 2021 e 2022',
    fontsize=18,
    pad=6
)

plt.xlabel('Meses', fontsize=14)
plt.ylabel('Cotacao do dolar R$', fontsize=14)

plt.legend()

plt.show()

# %% [markdown]
# ### Gráfico de setores
#
# É um gráfico comum para representar distribuições de frequências de variáveis qualitativas. É construido repartindo um disco em setores correspondentes às frequ~encias relativas de cada valor ou categoria. É particularmente útil quando o número de categorias não é grande e as categorias não obedecem a alguma ordem específica.
#
# Vantagem: todas as informações contidas na tabela de frequências podem ser transportadas para o gráfico.

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO  TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino            3        CE                     2.0
# 4                 2   Feminino            3        CE                     2.0
# 33                3  Masculino            1        BA                     2.0
# 45                4   Feminino            3        ES                     1.0
# 51                3  Masculino            3        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
# ...

# %%
enem_df['TP_COR_RACA'] = enem_df['TP_COR_RACA'].map({0: 'NA', 1:'Branca', 2: 'Preta', 3: 'Parda', 4: 'Amarela', 5: 'Indígena'})
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino       Parda        CE                     2.0
# 4                 2   Feminino       Parda        CE                     2.0
# 33                3  Masculino      Branca        BA                     2.0
# 45                4   Feminino       Parda        ES                     1.0
# 51                3  Masculino       Parda        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
enem_df['TP_COR_RACA'].value_counts(normalize=True)
# Out:
# Parda       0.447335
# Branca      0.412413
# Preta       0.100947
# Amarela     0.020500
# NA          0.015693
# Indígena    0.003110
# Name: TP_COR_RACA, dtype: float64

# %%
enem_df['TP_COR_RACA'].value_counts(normalize=True).plot.pie(
    figsize=(15,9),
    autopct='%1.1f%%',
    shadow=True
)
# Out:
# <Axes: ylabel='TP_COR_RACA'>

# %%
enem_df['TP_COR_RACA'].value_counts(normalize=True).plot.pie(
    figsize=(15,9),
    autopct='%1.1f%%',
    shadow=True
)

plt.ylabel('')

plt.title(
    'Porcentagem de alunos inscritos no ENEM 2021 por Etnia',
    fontsize=18,
    fontweight='bold'
)

plt.show()

# %% [markdown]
# ### Boxplot

# %% [markdown]
# o **Boxplot** (gráfico de caixa) é um gráfico utilizado para representar dados quantitativos sendo conveniente para revelar medidas de tendência central, dispersão, distribuição dos dados e a presença de outliers (valores discrepantes).
#
# O boxplot é formado pelo **primeiro** e **terceiro** quartil e pela **mediana**. As hastes inferiores e superiores se estendem, respectivamente, do quartil **inferior** até o **menor valor** não inferior ao **limite inferior** e do quartil **superior** até o **maior valor** não superior ao **limite superior**.
#
# **VARIAÇÃO INTERQUARTIL = Q3-Q1**
#
# Onde **Q3** (terceiro quartil) representa **75%** dos dados e **Q1** (primeiro quartil) representa **25%** dos dados.
#
# **IQR = Q3 = Q1**
#
# O **desvio padrão** e a **variância** dependem da **média**, e por isso são **afetados** por valores **extremos**. A **variação interquartil** (IQR em inglês), é uma medida de dispersão baseada na **mediana**, funciona de maneira bem mais **eficiente** na presença de **outliers**, ou seja, é pouco afetada pelo outliers.
#
# Os limites são **calculados** da seguinte forma:
#
# **Limite inferior (mínimo): Q1 - 1,5 * (Q3 - Q1)**
#
# **Limite superior (máximo): Q3 + 1,5 * (Q3 - Q1)**
#
# Os pontos dora destes limites são considerados valores **discrepantes (outliers)** e são denotados por asterisco (*). A figura a seguir apresenta um exemplo do formato de um boxplot.
#
# ![](https://www.abgconsultoria.com.br/blog/wp-content/uploads/boxplot-1-1024x664.png)
#
#
# Use o Boxplot para avaliar e comparar o formato, tendência central e variabilidade de distribuições de amostra, e para procurar por outliers. Um boxplot funciona melhor quando o tamanho amostral é de pelo menos 20. Por padrão, um boxplot demonstraa mediana, amplitude interquartil, amplitude e outliers para cada grupo.
#
# Fonte: [https://support.minitab.com/pt-br/minitab/21/help-and-how-to/graphs/boxplot/before-you-start/example/](https://support.minitab.com/pt-br/minitab/21/help-and-how-to/graphs/boxplot/before-you-start/example/)
#
#
# A forma da distribuição dos dados pode ser analisada por meio do diagrama em caixas de acordo com a figura a seguir, a distribuição amostral pode ser comparada com a distribuição também observada nos histogramas.
#
# ![](https://blog.proffernandamaciel.com.br/wp-content/uploads/2022/02/fig2.jpeg)
#
#
# ![](https://blog.proffernandamaciel.com.br/wp-content/uploads/2022/02/assimetria.jpeg)

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.boxplot(
    data=enem_df,
    x='TP_COR_RACA',
    y='NU_NOTA_REDACAO'
)

plt.show()

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino       Parda        CE                     2.0
# 4                 2   Feminino       Parda        CE                     2.0
# 33                3  Masculino      Branca        BA                     2.0
# 45                4   Feminino       Parda        ES                     1.0
# 51                3  Masculino       Parda        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
#    Q024 Q025  renda_familiar
# ...

# %%
def mapear_classe_social(categoria_renda):
  if categoria_renda in ['A', 'B']:
    return 'E'
  elif categoria_renda in ['C', 'D', 'E', 'F', 'G']:
    return 'D'
  elif categoria_renda in ['H', 'I', 'J', 'K', 'L', 'M']:
    return 'C'
  elif categoria_renda in ['N', 'O', 'P']:
    return 'B'
  else:
    return 'A'

# %%
enem_df['classe_social'] = enem_df['Q006'].apply(mapear_classe_social)
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino       Parda        CE                     2.0
# 4                 2   Feminino       Parda        CE                     2.0
# 33                3  Masculino      Branca        BA                     2.0
# 45                4   Feminino       Parda        ES                     1.0
# 51                3  Masculino       Parda        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
# ...

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.boxplot(
    data=enem_df,
    x='classe_social',
    y='NU_NOTA_REDACAO'
)

plt.show()

# %% [markdown]
# ### Gráfico de dispersão
#
# O modo padrão de visualizar o relacionamento entre duas variáveis de dados mensuradas. O eixo x representa uma variável, o eixo y, outra, e cada ponto no gráfico é um regristro.

# %%
enem_df.head()
# Out:
#     TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 3                 3  Masculino       Parda        CE                     2.0
# 4                 2   Feminino       Parda        CE                     2.0
# 33                3  Masculino      Branca        BA                     2.0
# 45                4   Feminino       Parda        ES                     1.0
# 51                3  Masculino       Parda        ES                     2.0
#
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006 Q022  \
# 3        580.7       678.9       638.9       659.5            780.0    B    B
# 4        497.7       532.4       457.6       582.6            780.0    C    E
# 33       414.6       410.1       386.7       423.0            700.0    B    C
# 45       476.8       608.5       534.2       570.2            640.0    C    C
# 51       433.4       622.0       548.3       579.4            680.0    D    D
#
# ...

# %%
sns.relplot(
    data=enem_df,
    x='NU_NOTA_LC',
    y='NU_NOTA_REDACAO'
)

plt.show()

# %%
sns.relplot(
    data=enem_df,
    x='NU_NOTA_LC',
    y='NU_NOTA_MT'
)

plt.show()
